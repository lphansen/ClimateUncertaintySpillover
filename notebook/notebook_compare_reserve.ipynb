# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()) + '/source')

import numpy as np
import matplotlib.pyplot as plt
from simulation import simulate_emission_quadratic, simulate_log_damage

np.random.seed(0)

# %%
# Model parameters
δ = 0.01
η = 0.032
median = 1.75/1000
h_hat = 0.2
σ_n = 1.5
γ_low = 0.012
γ_high = 0.024
ξ = σ_n/h_hat*δ*η

# Simulation setting
T = 500

# %%
ξ
# Out:
# 0.0024

# %% [markdown]
# ## 4. Compare $\xi$

# %%
r_start = 1500

# Simulate emission trajectory, 0.1x ξ
args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
Et_low_01x_1, r_grid_low_01x, _, e_grid_low_01x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*0.1, σ_n,
                                     args_trace_ϕ=args_trace_ϕ,
                                     r_start=r_start, T=T)

# %%
plt.plot(Et_low_01x_1)

# %%
Et_high_01x_1, r_grid_high_01x, _, e_grid_high_01x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*0.1, σ_n,
                                      args_trace_ϕ=args_trace_ϕ,
                                      r_start=r_start, T=T)

# # Simulate emission trajectory, 0.5x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_05x_1, r_grid_low_05x, _, e_grid_low_05x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*0.5, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_05x_1, r_grid_high_05x, _, e_grid_high_05x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*0.5, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# Simulate emission trajectory, 1x ξ
args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
Et_low_1, r_grid_low, _, e_grid_low = simulate_emission_quadratic(δ, η, median*γ_low, ξ, σ_n,
                                     args_trace_ϕ=args_trace_ϕ,
                                     r_start=r_start, T=T)
Et_high_1, r_grid_high, _, e_grid_high  = simulate_emission_quadratic(δ, η, median*γ_high, ξ, σ_n,
                                      args_trace_ϕ=args_trace_ϕ,
                                      r_start=r_start, T=T)

# # Simulate emission trajectory, 5x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_5x_1, r_grid_low_5x, _, e_grid_low_5x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*5, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_5x_1, r_grid_high_5x, _, e_grid_high_5x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*5, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# # Simulate emission trajectory, 10x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_10x_1, r_grid_low_10x, _, e_grid_low_10x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*10, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_10x_1, r_grid_high_10x, _, e_grid_high_10x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*10, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# %%
r_start = 1000

# Simulate emission trajectory, 0.1x ξ
args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
Et_low_01x_2, r_grid_low_01x, _, e_grid_low_01x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*0.1, σ_n,
                                     args_trace_ϕ=args_trace_ϕ,
                                     r_start=r_start, T=T)
Et_high_01x_2, r_grid_high_01x, _, e_grid_high_01x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*0.1, σ_n,
                                      args_trace_ϕ=args_trace_ϕ,
                                      r_start=r_start, T=T)

# # Simulate emission trajectory, 0.5x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_05x_2, r_grid_low_05x, _, e_grid_low_05x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*0.5, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_05x_2, r_grid_high_05x, _, e_grid_high_05x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*0.5, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# Simulate emission trajectory, 1x ξ
args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
Et_low_2, r_grid_low, _, e_grid_low = simulate_emission_quadratic(δ, η, median*γ_low, ξ, σ_n,
                                     args_trace_ϕ=args_trace_ϕ,
                                     r_start=r_start, T=T)
Et_high_2, r_grid_high, _, e_grid_high  = simulate_emission_quadratic(δ, η, median*γ_high, ξ, σ_n,
                                      args_trace_ϕ=args_trace_ϕ,
                                      r_start=r_start, T=T)

# # Simulate emission trajectory, 5x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_5x_2, r_grid_low_5x, _, e_grid_low_5x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*5, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_5x_2, r_grid_high_5x, _, e_grid_high_5x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*5, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# # Simulate emission trajectory, 10x ξ
# args_trace_ϕ = (-20, -5, 1000, 1e-9, 1e-3)
# Et_low_10x_2, r_grid_low_10x, _, e_grid_low_10x = simulate_emission_quadratic(δ, η, median*γ_low, ξ*10, σ_n,
#                                      args_trace_ϕ=args_trace_ϕ,
#                                      r_start=r_start, T=T)
# Et_high_10x_2, r_grid_high_10x, _, e_grid_high_10x  = simulate_emission_quadratic(δ, η, median*γ_high, ξ*10, σ_n,
#                                       args_trace_ϕ=args_trace_ϕ,
#                                       r_start=r_start, T=T)

# %%
color_set = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
# plt.plot(Et_low_10x_1, label=r'10x ξ, $r_0$=1500', color=color_set[0])
# plt.plot(Et_low_5x_1, label=r'tx ξ, $r_0$=1500', color=color_set[1])
plt.plot(Et_low_1, label=r'1x ξ, $r_0$=1500', color=color_set[0])
# plt.plot(Et_low_05x_1, label=r'0.5x ξ, $r_0$=1500', color=color_set[3])

plt.plot(Et_low_2, label=r'1x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')

plt.plot(Et_low_01x_1, label=r'0.1x ξ, $r_0$=1500', color=color_set[1])

# plt.plot(Et_low_10x_2, label=r'10x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')
# plt.plot(Et_low_5x_2, label=r'tx ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')
# plt.plot(Et_low_05x_2, label=r'0.5x ξ, $r_0$=1000', color=color_set[3], linestyle='dashed')
plt.plot(Et_low_01x_2, label=r'0.1x ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')

plt.legend()
plt.xlabel('Year')
plt.title('Figure 1: Emission trajectory (low damage)')
plt.savefig('figure_1.pdf')
plt.show()

# %%
# plt.plot(Et_high_10x_1, label=r'10x ξ, $r_0$=1500', color=color_set[0])
# plt.plot(Et_high_5x_1, label=r'5x ξ, $r_0$=1500', color=color_set[1])
plt.plot(Et_high_1, label=r'1x ξ, $r_0$=1500', color=color_set[0])
# plt.plot(Et_high_05x_1, label=r'0.5x ξ, $r_0$=1500', color=color_set[3])

plt.plot(Et_high_2, label=r'1x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')

plt.plot(Et_high_01x_1, label=r'0.1x ξ, $r_0$=1500', color=color_set[1])
# plt.plot(Et_high_10x_2, label=r'10x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')
# plt.plot(Et_high_5x_2, label=r'5x ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')
# plt.plot(Et_high_05x_2, label=r'0.5x ξ, $r_0$=1000', color=color_set[3], linestyle='dashed')
plt.plot(Et_high_01x_2, label=r'0.1x ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')

plt.legend()
plt.xlabel('Year')
plt.title('Figure 2: Emission trajectory (high damage)')
plt.savefig('figure_2.pdf')
plt.show()

# %%
# Calculate h_hat
h_hat_implied_low_1 = Et_low_1*(median*γ_low)*σ_n/ξ
h_hat_implied_low_2 = Et_low_2*(median*γ_low)*σ_n/ξ
h_hat_implied_low_01x_1 = Et_low_01x_1*(median*γ_low)*σ_n/(ξ*0.1)
h_hat_implied_low_01x_2 = Et_low_01x_2*(median*γ_low)*σ_n/(ξ*0.1)

h_hat_implied_high_1 = Et_high_1*(median*γ_high)*σ_n/ξ
h_hat_implied_high_2 = Et_high_2*(median*γ_high)*σ_n/ξ
h_hat_implied_high_01x_1 = Et_high_01x_1*(median*γ_high)*σ_n/(ξ*0.1)
h_hat_implied_high_01x_2 = Et_high_01x_2*(median*γ_high)*σ_n/(ξ*0.1)

# %%
plt.plot(h_hat_implied_low_1, label=r'1x ξ, $r_0$=1500', color=color_set[0])
plt.plot(h_hat_implied_low_2, label=r'1x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')
plt.plot(h_hat_implied_low_01x_1, label=r'0.1x ξ, $r_0$=1500', color=color_set[1])
plt.plot(h_hat_implied_low_01x_2, label=r'0.1x ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')

plt.legend()
plt.xlabel('Year')
plt.title(r'Figure 3: Implied $\hat{h}$ (low damage)')
plt.savefig('figure_3.pdf')
plt.show()

# %%
plt.plot(h_hat_implied_high_1, label=r'1x ξ, $r_0$=1500', color=color_set[0])
plt.plot(h_hat_implied_high_2, label=r'1x ξ, $r_0$=1000', color=color_set[0], linestyle='dashed')
plt.plot(h_hat_implied_high_01x_1, label=r'0.1x ξ, $r_0$=1500', color=color_set[1])
plt.plot(h_hat_implied_high_01x_2, label=r'0.1x ξ, $r_0$=1000', color=color_set[1], linestyle='dashed')

plt.legend()
plt.xlabel('Year')
plt.title(r'Figure 4: Implied $\hat{h}$ (high damage)')
plt.savefig('figure_4.pdf')
plt.show()
