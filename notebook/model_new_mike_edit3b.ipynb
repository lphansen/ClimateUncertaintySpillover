# %%
# packages
import numpy as np
import pandas as pd
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()) + '/source')
import pickle
from solver_1d import false_transient_one_iteration_python
from supportfunctions import PDESolver_2d, finiteDiff
from numba import njit
from scipy.sparse import csc_matrix
from scipy.sparse.linalg import bicg
import SolveLinSys
import time
from derivative import derivatives_2d
from solver_ode import solve_ode, solve_ode_one, derivative_1d, solve_ode_neumann
from solver_jump import approach_one_100, solve_smooth_100, solve_jump_100
from scipy import interpolate
import matplotlib.pyplot as plt
import matplotlib as mpl
import time
import matplotlib.transforms as transforms
from scipy.interpolate import RegularGridInterpolator, CubicSpline
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['figure.facecolor'] = 'w'
mpl.rcParams['figure.edgecolor'] = 'w'

# %%
# parameters
δ = 0.01
η = 0.032
μ = 1.86/1000
θ_list = pd.read_csv("../data/model144.csv", header=None)[0].to_numpy()
θ_list = θ_list/1000
σy = 1.2*np.mean(θ_list)
# damage function
# ȳ = 1.9
γ1 = 0.00017675
γ2 = 2*0.0022
# γ3_list = np.linspace(0, 1/3, 40)
# γ3_list = np.array([0, 0.0197*2, 0.3853*2])
y_jump=2
y = 2.5
damage_min =  γ1*(y- y_jump+2) + γ2/2*(y - y_jump+2)**2
damage_max =  γ1*(y- y_jump+2) + γ2/2*(y - y_jump+2)**2 + 1/3/2*(y - y_jump)**2
damages = np.linspace(np.exp(-damage_max), np.exp(-damage_min), 40)
γ3_list = 2*( - np.log(damages) - γ1*(y- y_jump+2) - γ2/2*(y - y_jump+2)**2)/(y - y_jump)**2
γ3_list = np.flip(γ3_list)
γ3_list[0] = 0
# γ3_list[0] = 0.0197*2

dmg_weight = np.ones(len(γ3_list))/len(γ3_list)
# capital parameters
invkap = 0.09
α = 0.115
μk = - 0.043
σk = 0.0085
κ = 6.667
k0 = 80/α

# %%
y_step = 0.05
y_grid = np.arange(0., 4 + y_step, y_step)

k_step = 0.05
k_grid = np.arange(0., 9 + k_step, k_step)

(y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
hy = y_grid[1] - y_grid[0]
hk = k_grid[1] - k_grid[0]
n_y = len(y_grid)
n_k = len(k_grid)

# %%
y_mat.shape
# Out:
# (81, 181)

# %%
def solve_new(y_grid, k_grid, args, ϵ=0.5, max_iter=2000, tol=1e-6):
    δ, η, α, μk, σk, κ, θ, θ_list, σy, γ1, γ2, γ3, y_bar, ξa, ϑ_bar, λ_bar = args
    n_y = len(y_grid)
    n_k = len(k_grid)
    dy = y_grid[1] - y_grid[0]
    dk = k_grid[1] - k_grid[0]
    (y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
    stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
    πa_o = np.ones((len(θ_list), n_y, n_k))/len(θ_list)
    θ_mat = np.zeros((len(θ_list), n_y, n_k))
    for i in range(len(θ_list)):
        θ_mat[i] = θ_list[i]
    πa = πa_o
    
    dΛ = γ1 + γ2*y_mat + γ3*(y_mat - y_bar)*(y_mat >y_bar)
    ddΛ = γ2 + γ3*(y_mat > y_bar)
    v0 =  -  η*y_mat**2 + k_mat**2
    ems_new = η*y_mat**2 + k_mat**2
    ems_old = ems_new
    episode = 0
    lhs_error = 0.5
    vd = - 1/δ
    while lhs_error > tol:
        if episode ==0:
            i = 0
            ems = ems_new
            mc_new = 1/(α - i - np.exp(ϑ_bar)*(1 - np.exp(λ_bar)*(ems/np.exp(k_mat))**θ) )
        else:
            vold = v0.copy()
        v0_dy = derivatives_2d(v0,0,1,dy)
        v0_dyy = derivatives_2d(v0,0,2,dy)
        v0_dk = derivatives_2d(v0,1,1,dk)
#         v0_dy2[v0_dy2 > - 1e-15] =  - 1e-15
        v0_dkk = derivatives_2d(v0,1,2,dk)
        # updating controls
        mc = mc_new
        i_new = 1 - mc/v0_dk
        # update emission
        a = v0_dyy*σy**2 + vd*ddΛ*σy**2 - mc*θ*np.exp(ϑ_bar)*np.exp(2*(λ_bar-k_mat))
        b = mc*θ*np.exp(ϑ_bar + λ_bar - k_mat) + v0_dy*np.sum(θ_mat*πa, axis=0) \
            + vd*dΛ*np.sum(θ_mat*πa, axis=0)
        ems_new = -b/a
        ems_new[ems_new < 1e-15] = 1e-15
        mc_new = 1/(α - i_new - np.exp(ϑ_bar)*(1 - np.exp(λ_bar)*(ems_new/np.exp(k_mat))**θ) )
#         ems_new[ems_new <= 1e-15] = 1e-15
#         ems = ems_new*0.5 + ems_old*0.5

#         weight = np.array([-1/ξa*v0_dy2*λ*ems*θ for θ in θ_list])
#         weight = weight - np.max(weight, axis=0)
#         πa = πa_o*np.exp(weight)
#         πa[πa<1e-15] = 1e-15
#         πa = πa/np.sum(πa, axis=0)
        print(np.min(ems_new))
        # HJB coefficient
        entropy = np.sum(πa*(np.log(πa) - np.log(πa_o)), axis=0)
        A =  -δ*np.ones(y_mat.shape)
        B_y = np.sum(θ_mat*πa, axis=0)*ems
        B_k = μk + i_new - 0.5*κ*i_new**2 - 0.5*σk**2
        C_yy = 0.5*ems**2*σy**2
        C_kk = 0.5*σk**2*np.ones(y_mat.shape)
        D = np.log(mc_new) + k_mat + vd*(dΛ*np.sum(θ_mat*πa, axis=0)*ems_new + 0.5*ddΛ*σy**2*ems_new**2) \
            + ξa*entropy
        # PDE solver
        out = PDESolver_2d(stateSpace, A, B_y, B_k, C_yy, C_kk, D, v0, ϵ, solverType = 'False Transient')
        out_comp = out[2].reshape(v0.shape,order = "F")
        rhs = A*v0 + B_y*v0_dy + B_k*v0_dk + C_yy*v0_dyy + C_kk*v0_dkk  + D
        rhs_error = np.max(abs(rhs))
        lhs_error = np.max(abs((out_comp - v0)/ϵ))
        #     if episode % 1 == 0:
        print("Episode {:d}: PDE Error: {:.12f}; False Transient Error: {:.12f}; Iterations: {:d}; CG Error: {:.12f}".format(episode, rhs_error, lhs_error, out[0], out[1]))
        episode += 1
        v0 = out_comp
        ems_old = ems_new
    result = dict(v0=v0, ems=ems, πa=πa)
    return result

# %% [markdown]
# $$
# mc = \frac{1}{\alpha - i - \alpha \vartheta (1 - \frac{e}{\alpha \lambda  \exp(k)})^\theta}
# $$
#
# First order condition for $i$:
#
# $$
#  - mc + \frac{d\phi}{dk} (1 - \kappa i) = 0
# $$
#
# FOC for $e$:
#
# $$
# mc (\bar{\vartheta} \theta \frac{1 }{\lambda \exp (k)}  (1 - \frac{e}{\alpha \lambda \exp{k}})^{\theta - 1}) +
# $$

# %%
# HJB for ϕ_m
θ = 3
y_bar = 2
ξa = 0.01
# ξa = 10000
ξb = 3
# ξb = 10000
# ϑ_bar = 0.078
ϑ_bar = 0.036
# λ_bar = 0.134
λ_bar = 0.102
γ3 = γ3_list[0]

α=0.115

ϵ=2.5


max_iter=2000
tol=1e-7

n_y = len(y_grid)
n_k = len(k_grid)
dy = y_grid[1] - y_grid[0]
dk = k_grid[1] - k_grid[0]

(y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
πa_o = np.ones((len(θ_list), n_y, n_k))/len(θ_list)
θ_mat = np.zeros((len(θ_list), n_y, n_k))
for i in range(len(θ_list)):
    θ_mat[i] = θ_list[i]
πa = πa_o

dΛ = γ1 + γ2*y_mat + γ3*(y_mat - y_bar)*(y_mat >y_bar)
ddΛ = γ2 + γ3*(y_mat > y_bar)

# initial guess
v0 =  (1/δ)*k_mat  -  η/δ*y_mat**2 
# initial i
a_i = κ*(1/δ)
b_i = - (1 + α*κ)*(1/δ)
c_i = α*(1/δ) - 1
i = (-b_i - np.sqrt(b_i**2 - 4*a_i*c_i))/(2*a_i)

ems = 0*np.ones(y_mat.shape)
mc = 1/(α - i - α*ϑ_bar*(1 - ems/(np.exp(k_mat)*α*λ_bar))**θ )

episode = 0
lhs_error = 0.5
vd = - 1/δ

while lhs_error > tol:
    vold = v0.copy()
    v0_dy = derivatives_2d(v0,0,1,dy)
    v0_dyy = derivatives_2d(v0,0,2,dy)
    v0_dk = derivatives_2d(v0,1,1,dk)
    v0_dk[v0_dk < 1e-15] =  1e-15
    v0_dkk = derivatives_2d(v0,1,2,dk)
    # updating controls
    i_new = (1 -mc/v0_dk)*(1/κ)
#     update emission
#     a = v0_dyy*σy**2 + vd*ddΛ*σy**2 - mc*θ*ϑ_bar/(α*λ_bar**2*np.exp(2*k_mat))
#     b = mc*θ*ϑ_bar/(λ_bar*np.exp(k_mat)) + v0_dy*np.sum(θ_mat*πa, axis=0) \
#         + vd*dΛ*np.sum(θ_mat*πa, axis=0)
#     ems_new = - b/a
    b = v0_dyy*σy**2 + vd*ddΛ*σy**2 - mc*θ*ϑ_bar*2/(α*λ_bar**2*np.exp(2*k_mat))
    c = mc*θ*ϑ_bar/(λ_bar*np.exp(k_mat)) + v0_dy*np.sum(θ_mat*πa, axis=0) \
        + vd*dΛ*np.sum(θ_mat*πa, axis=0)
    a = mc*θ*ϑ_bar/(α**2*λ_bar**3*np.exp(3*k_mat))
    
    ems_new = (- b-np.sqrt(b**2-4*a*c))/(2*a)
#     ems_new[ems_new < 1e-15] = 1e-15
    i_new = i_new*0.05 + i*0.95
    ems_new = ems_new*0.05 + ems*0.95
    ratio = (1 - ems_new/(α*λ_bar*np.exp(k_mat)))*( (1 - ems_new/(α*λ_bar*np.exp(k_mat))) > 0 )
    consumption = α - i_new - α*ϑ_bar*ratio**θ
#     consumption[c# mc[mc < 1e-15] = 1e-1510onsumption <= 1e-15] = 1e-15
    mc_new = 1/consumption
    
#     mc_new[mc_new <= 1e-15] = 1e-15
#     mc_new = mc_new*0.05 + mc*0.95
    temp = v0_dy + vd*dΛ
    weight = np.array([-1/ξa*temp*ems_new*θ for θ in θ_list])
    weight = weight - np.max(weight, axis=0)
    πa = πa_o*np.exp(weight)
    πa[πa<1e-15] = 1e-15
    πa = πa/np.sum(πa, axis=0)
    print("min ems:", np.min(ems_new))
    print("min mc", np.min(mc_new))
    # HJB coefficient
    entropy = np.sum(πa*(np.log(πa) - np.log(πa_o)), axis=0)
    A =  -δ*np.ones(y_mat.shape)
    B_y = np.sum(θ_mat*πa, axis=0)*ems_new
    B_k = μk + i_new - 0.5*κ*i_new**2 - 0.5*σk**2
    C_yy = 0.5*ems_new**2*σy**2
    C_kk = 0.5*σk**2*np.ones(y_mat.shape)
    D = - np.log(mc_new) + k_mat + vd*(dΛ*np.sum(θ_mat*πa, axis=0)*ems_new + 0.5*ddΛ*σy**2*ems_new**2) \
        + ξa*entropy
    # PDE solver
    out = PDESolver_2d(stateSpace, A, B_y, B_k, C_yy, C_kk, D, v0, ϵ, solverType = 'False Transient')
    out_comp = out[2].reshape(v0.shape,order = "F")
    rhs = A*v0 + B_y*v0_dy + B_k*v0_dk + C_yy*v0_dyy + C_kk*v0_dkk  + D
    rhs_error = np.max(abs(rhs))
    lhs_error = np.max(abs((out_comp - v0)/ϵ))
    #     if episode % 1 == 0:
    print("Episode {:d}: PDE Error: {:.12f}; False Transient Error: {:.12f}; Iterations: {:d}; CG Error: {:.12f}".format(episode, rhs_error, lhs_error, out[0], out[1]))
    episode += 1
    v0 = out_comp
    ems = ems_new
    mc = mc_new
    i = i_new
# Out:
# min ems: -8.0146605914167
# min mc 45.360406153541035
# Episode 0: PDE Error: 1.864440716708; False Transient Error: 1.819777490664; Iterations: 51; CG Error: 0.000000000097
# min ems: -12.215710297259264
# min mc 43.62391477177613
# Episode 1: PDE Error: 1.815766599799; False Transient Error: 1.772513081422; Iterations: 62; CG Error: 0.000000000093
# min ems: -15.938849572672078
# min mc 42.408858436644074
# Episode 2: PDE Error: 1.769782209695; False Transient Error: 1.727902297582; Iterations: 75; CG Error: 0.000000000088
# min ems: -19.255233514317673
# min mc 41.54069518026281
# Episode 3: PDE Error: 1.725769275626; False Transient Error: 1.685054580462; Iterations: 89; CG Error: 0.000000000074
# min ems: -22.19262875418311
# min mc 40.91397191347614
# Episode 4: PDE Error: 1.683320123541; False Transient Error: 1.643654941421; Iterations: 101; CG Error: 0.000000000082
# min ems: -24.767414187899725
# min mc 40.460561106010275
# Episode 5: PDE Error: 1.642166478936; False Transient Error: 1.603588779249; Iterations: 112; CG Error: 0.000000000092
# min ems: -26.994202967689674
# min mc 40.13419952985092
# Episode 6: PDE Error: 1.602134646586; False Transient Error: 1.564575025581; Iterations: 121; CG Error: 0.000000000086
# min ems: -28.888752399156502
# min mc 39.90226117469581
# Episode 7: PDE Error: 1.563276887732; False Transient Error: 1.526645812888; Iterations: 128; CG Error: 0.000000000075
# min ems: -30.46846452544401
# min mc 39.741065625458916
# Episode 8: PDE Error: 1.525390743767; False Transient Error: 1.489668560239; Iterations: 134; CG Error: 0.000000000092
# min ems: -31.752120088039135
# min mc 39.633048004898114
# Episode 9: PDE Error: 1.488560256207; False Transient Error: 1.453684402872; Iterations: 140; CG Error: 0.000000000091
# min ems: -32.75933714966357
# min mc 39.56496937885722
# Episode 10: PDE Error: 1.452657682286; False Transient Error: 1.418613431745; Iterations: 143; CG Error: 0.000000000087
# min ems: -33.51005587711692
# min mc 39.52673803551595
# Episode 11: PDE Error: 1.417768946483; False Transient Error: 1.384426324720; Iterations: 144; CG Error: 0.000000000100
# min ems: -34.024093233000585
# min mc 39.51060483270356
# Episode 12: PDE Error: 1.384131279666; False Transient Error: 1.351051916380; Iterations: 145; CG Error: 0.000000000087
# min ems: -34.32080966104474
# min mc 39.510596197249214
# Episode 13: PDE Error: 1.350975544771; False Transient Error: 1.318439734003; Iterations: 145; CG Error: 0.000000000087
# min ems: -34.418881493795965
# min mc 39.522103287869896
# Episode 14: PDE Error: 1.318365267398; False Transient Error: 1.286424783089; Iterations: 144; CG Error: 0.000000000095
# min ems: -34.336153260998145
# min mc 39.54157702303151
# Episode 15: PDE Error: 1.286347169387; False Transient Error: 1.255039821573; Iterations: 144; CG Error: 0.000000000090
# min ems: -34.0895474693751
# min mc 39.56629701024578
# Episode 16: PDE Error: 1.254955789102; False Transient Error: 1.224311153514; Iterations: 143; CG Error: 0.000000000098
# min ems: -33.69501604108564
# min mc 39.58460291013742
# Episode 17: PDE Error: 1.224218832934; False Transient Error: 1.194261354334; Iterations: 139; CG Error: 0.000000000095
# min ems: -33.16751455257672
# min mc 39.58780047708821
# Episode 18: PDE Error: 1.194160248967; False Transient Error: 1.164910316331; Iterations: 139; CG Error: 0.000000000097
# min ems: -32.52099724314314
# min mc 39.58409777307622
# Episode 19: PDE Error: 1.164801057699; False Transient Error: 1.136271138946; Iterations: 136; CG Error: 0.000000000092
# min ems: -31.768412946407594
# min mc 39.57577584105926
# Episode 20: PDE Error: 1.136155217290; False Transient Error: 1.108343907358; Iterations: 132; CG Error: 0.000000000090
# min ems: -30.921727889371727
# min mc 39.56420459500691
# Episode 21: PDE Error: 1.108223169410; False Transient Error: 1.081110137588; Iterations: 129; CG Error: 0.000000000085
# min ems: -29.991963090943354
# min mc 39.55027089050016
# Episode 22: PDE Error: 1.080985825089; False Transient Error: 1.054530000834; Iterations: 121; CG Error: 0.000000000095
# min ems: -28.98926064528644
# min mc 39.53473710337219
# Episode 23: PDE Error: 1.054401904900; False Transient Error: 1.028544596285; Iterations: 121; CG Error: 0.000000000100
# min ems: -27.92296935551777
# min mc 39.51804931335996
# Episode 24: PDE Error: 1.028410722214; False Transient Error: 1.003084280716; Iterations: 109; CG Error: 0.000000000095
# min ems: -26.801758124870428
# min mc 39.50068880225935
# Episode 25: PDE Error: 1.002940652121; False Transient Error: 0.978080159060; Iterations: 110; CG Error: 0.000000000090
# min ems: -25.63373925972958
# min mc 39.48291645743283
# Episode 26: PDE Error: 0.977921030471; False Transient Error: 0.953478201583; Iterations: 106; CG Error: 0.000000000099
# min ems: -24.426592785831723
# min mc 39.46500067123578
# Episode 27: PDE Error: 0.953296379620; False Transient Error: 0.929247497284; Iterations: 103; CG Error: 0.000000000095
# min ems: -23.18767373869328
# min mc 39.4472046949603
# Episode 28: PDE Error: 0.929035391911; False Transient Error: 0.905385011221; Iterations: 98; CG Error: 0.000000000087
# min ems: -21.924122737528407
# min mc 39.429751977972764
# Episode 29: PDE Error: 0.905135870931; False Transient Error: 0.881912986554; Iterations: 98; CG Error: 0.000000000086
# min ems: -20.642894237242675
# min mc 39.41266051865929
# Episode 30: PDE Error: 0.881622373572; False Transient Error: 0.858870584325; Iterations: 96; CG Error: 0.000000000082
# min ems: -19.350807818939657
# min mc 39.39625786214602
# Episode 31: PDE Error: 0.858537596656; False Transient Error: 0.836303776698; Iterations: 90; CG Error: 0.000000000081
# min ems: -18.05452655121589
# min mc 39.38057652879099
# Episode 32: PDE Error: 0.836010247275; False Transient Error: 0.814254084137; Iterations: 91; CG Error: 0.000000000085
# min ems: -16.76051329530665
# min mc 39.365655024291875
# Episode 33: PDE Error: 0.814183276318; False Transient Error: 0.792809180203; Iterations: 88; CG Error: 0.000000000099
# min ems: -15.474962502847866
# min mc 39.35153490764815
# Episode 34: PDE Error: 0.792977552652; False Transient Error: 0.772046002632; Iterations: 90; CG Error: 0.000000000083
# min ems: -14.203679560924407
# min mc 39.33825849512603
# Episode 35: PDE Error: 0.772343989586; False Transient Error: 0.751860445583; Iterations: 89; CG Error: 0.000000000084
# min ems: -12.951871277313147
# min mc 39.325867101308205
# Episode 36: PDE Error: 0.752256315718; False Transient Error: 0.732213840632; Iterations: 90; CG Error: 0.000000000087
# min ems: -11.723863086832191
# min mc 39.31439972653357
# Episode 37: PDE Error: 0.732680199607; False Transient Error: 0.713072472128; Iterations: 91; CG Error: 0.000000000089
# min ems: -10.522747486945464
# min mc 39.30386246679849
# Episode 38: PDE Error: 0.713597752829; False Transient Error: 0.694420420967; Iterations: 91; CG Error: 0.000000000081
# min ems: -9.350066936095832
# min mc 39.294238870605625
# Episode 39: PDE Error: 0.694995916467; False Transient Error: 0.676240095137; Iterations: 92; CG Error: 0.000000000090
# min ems: -8.205656526722626
# min mc 39.28548323279058
# Episode 40: PDE Error: 0.676857702996; False Transient Error: 0.658660278504; Iterations: 94; CG Error: 0.000000000083
# min ems: -7.08770987487908
# min mc 39.27761917272987
# Episode 41: PDE Error: 0.659194320388; False Transient Error: 0.641960839261; Iterations: 98; CG Error: 0.000000000096
# min ems: -5.993084906239827
# min mc 39.270663655198604
# Episode 42: PDE Error: 0.642392208260; False Transient Error: 0.625712628672; Iterations: 102; CG Error: 0.000000000098
# min ems: -4.917753902420365
# min mc 39.26460419438726
# Episode 43: PDE Error: 0.626043661324; False Transient Error: 0.609896937406; Iterations: 105; CG Error: 0.000000000092
# min ems: -3.85729059738649
# min mc 39.25942355149854
# Episode 44: PDE Error: 0.610132918750; False Transient Error: 0.594496986686; Iterations: 108; CG Error: 0.000000000083
# min ems: -2.8072864815454643
# min mc 39.25510263259187
# Episode 45: PDE Error: 0.594644029133; False Transient Error: 0.579514709342; Iterations: 110; CG Error: 0.000000000095
# min ems: -1.7636507114880664
# min mc 39.25159503648239
# Episode 46: PDE Error: 0.579575064324; False Transient Error: 0.564918136752; Iterations: 113; CG Error: 0.000000000081
# min ems: -0.722783046044225
# min mc 39.24888481163421
# Episode 47: PDE Error: 0.564902390890; False Transient Error: 0.550717468609; Iterations: 117; CG Error: 0.000000000088
# min ems: 0.010519416820531794
# min mc 39.24694865100646
# Episode 48: PDE Error: 0.550621197822; False Transient Error: 0.536881282542; Iterations: 122; CG Error: 0.000000000098
# min ems: 0.010568021636313837
# min mc 39.24558550080913
# Episode 49: PDE Error: 0.536716736588; False Transient Error: 0.523412662347; Iterations: 126; CG Error: 0.000000000093
# min ems: 0.01061431447562945
# min mc 39.24450802211676
# Episode 50: PDE Error: 0.523182596574; False Transient Error: 0.510295707279; Iterations: 130; CG Error: 0.000000000082
# min ems: 0.01065840917605932
# min mc 39.24328947892136
# Episode 51: PDE Error: 0.509999269485; False Transient Error: 0.497515005488; Iterations: 133; CG Error: 0.000000000094
# min ems: 0.01070041390646429
# min mc 39.24129795602665
# Episode 52: PDE Error: 0.497172284988; False Transient Error: 0.485073955150; Iterations: 144; CG Error: 0.000000000079
# min ems: 0.010740431449777802
# min mc 39.23985321930746
# Episode 53: PDE Error: 0.484675807247; False Transient Error: 0.472954448557; Iterations: 152; CG Error: 0.000000000091
# min ems: 0.010778559471717035
# min mc 39.23915187636459
# Episode 54: PDE Error: 0.472506315038; False Transient Error: 0.461144677201; Iterations: 161; CG Error: 0.000000000099
# min ems: 0.010814890776112293
# min mc 39.23888032156004
# Episode 55: PDE Error: 0.460660425251; False Transient Error: 0.449638604674; Iterations: 170; CG Error: 0.000000000100
# min ems: 0.010849513547513635
# min mc 39.239073590859164
# Episode 56: PDE Error: 0.449119013463; False Transient Error: 0.438436134228; Iterations: 179; CG Error: 0.000000000090
# min ems: 0.010882511581707839
# min mc 39.23994420845518
# Episode 57: PDE Error: 0.437874140729; False Transient Error: 0.427518788992; Iterations: 187; CG Error: 0.000000000096
# min ems: 0.010913964504746533
# min mc 39.2411879659842
# Episode 58: PDE Error: 0.426929500788; False Transient Error: 0.416879081284; Iterations: 196; CG Error: 0.000000000095
# min ems: 0.01094394798105843
# min mc 39.242926604375334
# Episode 59: PDE Error: 0.416265914326; False Transient Error: 0.406509796915; Iterations: 205; CG Error: 0.000000000095
# min ems: 0.010972533911183132
# min mc 39.245207540506094
# Episode 60: PDE Error: 0.405875147184; False Transient Error: 0.396407489672; Iterations: 213; CG Error: 0.000000000098
# min ems: 0.010999790619643122
# min mc 39.24785801532669
# Episode 61: PDE Error: 0.395750030410; False Transient Error: 0.386566064539; Iterations: 222; CG Error: 0.000000000097
# min ems: 0.01102578303344523
# min mc 39.25083298515404
# Episode 62: PDE Error: 0.385889697344; False Transient Error: 0.376973556890; Iterations: 234; CG Error: 0.000000000091
# min ems: 0.01105057285168044
# min mc 39.254229827720174
# Episode 63: PDE Error: 0.376283623293; False Transient Error: 0.367623472804; Iterations: 243; CG Error: 0.000000000089
# min ems: 0.011074218706658779
# min mc 39.2579992901887
# Episode 64: PDE Error: 0.366921925829; False Transient Error: 0.358509489901; Iterations: 247; CG Error: 0.000000000089
# min ems: 0.011096776317011824
# min mc 39.262031915312015
# Episode 65: PDE Error: 0.357798166656; False Transient Error: 0.349625435942; Iterations: 265; CG Error: 0.000000000094
# min ems: 0.0111182986331278
# min mc 39.2662867666962
# Episode 66: PDE Error: 0.348906078631; False Transient Error: 0.340965311771; Iterations: 264; CG Error: 0.000000000096
# min ems: 0.01113883597543129
# min mc 39.27081749278711
# Episode 67: PDE Error: 0.340239557067; False Transient Error: 0.332526776512; Iterations: 288; CG Error: 0.000000000096
# min ems: 0.011158436165460703
# min mc 39.27558550093592
# Episode 68: PDE Error: 0.331798502800; False Transient Error: 0.324301822186; Iterations: 297; CG Error: 0.000000000093
# min ems: 0.011177144650977317
# min mc 39.28055542902188
# Episode 69: PDE Error: 0.323570936746; False Transient Error: 0.316283284954; Iterations: 303; CG Error: 0.000000000093
# min ems: 0.011195004624048549
# min mc 39.285695070291226
# Episode 70: PDE Error: 0.315551066748; False Transient Error: 0.308465819944; Iterations: 317; CG Error: 0.000000000091
# min ems: 0.01121205713405756
# min mc 39.290975274522566
# Episode 71: PDE Error: 0.307733462663; False Transient Error: 0.300844228323; Iterations: 327; CG Error: 0.000000000092
# min ems: 0.011228341194533682
# min mc 39.29636984082556
# Episode 72: PDE Error: 0.300112838407; False Transient Error: 0.293413458699; Iterations: 331; CG Error: 0.000000000097
# min ems: 0.011243893884601786
# min mc 39.301855384661
# Episode 73: PDE Error: 0.292684054541; False Transient Error: 0.286168583987; Iterations: 338; CG Error: 0.000000000098
# min ems: 0.011258750445424667
# min mc 39.3074112536164
# Episode 74: PDE Error: 0.285442112504; False Transient Error: 0.279104824483; Iterations: 353; CG Error: 0.000000000092
# min ems: 0.01127294437259259
# min mc 39.31301936895865
# Episode 75: PDE Error: 0.278382146329; False Transient Error: 0.272217518327; Iterations: 359; CG Error: 0.000000000100
# min ems: 0.011286507502788763
# min mc 39.31866413616827
# Episode 76: PDE Error: 0.271501190225; False Transient Error: 0.265502135692; Iterations: 362; CG Error: 0.000000000095
# min ems: 0.011299470096812685
# min mc 39.324332338764975
# Episode 77: PDE Error: 0.264794094257; False Transient Error: 0.258954263971; Iterations: 367; CG Error: 0.000000000099
# min ems: 0.011311860918086275
# min mc 39.33001300833486
# Episode 78: PDE Error: 0.258254870141; False Transient Error: 0.253670034942; Iterations: 372; CG Error: 0.000000000096
# min ems: 0.011323707307364613
# min mc 39.33561138267661
# Episode 79: PDE Error: 0.253657666538; False Transient Error: 0.251049930800; Iterations: 374; CG Error: 0.000000000097
# min ems: 0.011335035253866426
# min mc 39.341205402438874
# Episode 80: PDE Error: 0.251028503614; False Transient Error: 0.248380356684; Iterations: 376; CG Error: 0.000000000098
# min ems: 0.011345869462794788
# min mc 39.34679226727489
# Episode 81: PDE Error: 0.248349216831; False Transient Error: 0.245651149671; Iterations: 378; CG Error: 0.000000000094
# min ems: 0.011356233419183433
# min mc 39.352336000217235
# Episode 82: PDE Error: 0.245610387292; False Transient Error: 0.242856512081; Iterations: 365; CG Error: 0.000000000098
# min ems: 0.011366149448959105
# min mc 39.35782171011892
# Episode 83: PDE Error: 0.242806752316; False Transient Error: 0.239993564075; Iterations: 379; CG Error: 0.000000000095
# min ems: 0.011375638776799658
# min mc 39.363309971717044
# Episode 84: PDE Error: 0.239935773416; False Transient Error: 0.237062468459; Iterations: 380; CG Error: 0.000000000092
# min ems: 0.011384721580962
# min mc 39.368806368373036
# Episode 85: PDE Error: 0.236997917059; False Transient Error: 0.234065896299; Iterations: 379; CG Error: 0.000000000099
# min ems: 0.011393417045807396
# min mc 39.3743126244485
# Episode 86: PDE Error: 0.233995927413; False Transient Error: 0.231008090167; Iterations: 378; CG Error: 0.000000000099
# min ems: 0.011401743411108665
# min mc 39.37980591457786
# Episode 87: PDE Error: 0.230934078545; False Transient Error: 0.227894466491; Iterations: 375; CG Error: 0.000000000091
# min ems: 0.011409718019282472
# min mc 39.38534743397502
# Episode 88: PDE Error: 0.227817749452; False Transient Error: 0.224731127334; Iterations: 368; CG Error: 0.000000000096
# min ems: 0.01141735736005429
# min mc 39.39094888681775
# Episode 89: PDE Error: 0.224653045576; False Transient Error: 0.221525291447; Iterations: 369; CG Error: 0.000000000097
# min ems: 0.011424677113004895
# min mc 39.39662265018415
# Episode 90: PDE Error: 0.221447072519; False Transient Error: 0.218284791385; Iterations: 371; CG Error: 0.000000000099
# min ems: 0.011431692188168363
# min mc 39.40238147395673
# Episode 91: PDE Error: 0.218207375374; False Transient Error: 0.215016892659; Iterations: 371; CG Error: 0.000000000097
# min ems: 0.011438416764276323
# min mc 39.408238103781606
# Episode 92: PDE Error: 0.214941119701; False Transient Error: 0.211728659324; Iterations: 369; CG Error: 0.000000000092
# min ems: 0.011444864325411572
# min mc 39.414149732015275
# Episode 93: PDE Error: 0.211655232899; False Transient Error: 0.208426990542; Iterations: 370; CG Error: 0.000000000097
# min ems: 0.011451047695428016
# min mc 39.420156617713886
# Episode 94: PDE Error: 0.208356465726; False Transient Error: 0.205118264194; Iterations: 364; CG Error: 0.000000000097
# min ems: 0.011456979070866149
# min mc 39.42627688483008
# Episode 95: PDE Error: 0.205051069298; False Transient Error: 0.201808568392; Iterations: 361; CG Error: 0.000000000097
# min ems: 0.011462670052577678
# min mc 39.432519286118485
# Episode 96: PDE Error: 0.201745001236; False Transient Error: 0.198503529289; Iterations: 360; CG Error: 0.000000000096
# min ems: 0.01146813167500756
# min mc 39.438843803373594
# Episode 97: PDE Error: 0.198443784328; False Transient Error: 0.195208255356; Iterations: 354; CG Error: 0.000000000098
# min ems: 0.011473374434672485
# min mc 39.445215946650826
# Episode 98: PDE Error: 0.195152417223; False Transient Error: 0.191927354268; Iterations: 351; CG Error: 0.000000000093
# min ems: 0.011478408316838424
# min mc 39.451708463412864
# Episode 99: PDE Error: 0.191875454163; False Transient Error: 0.188665024993; Iterations: 348; CG Error: 0.000000000098
# min ems: 0.011483242821010436
# min mc 39.45828980031253
# Episode 100: PDE Error: 0.188617018331; False Transient Error: 0.185424980947; Iterations: 343; CG Error: 0.000000000100
# min ems: 0.011487886985374021
# min mc 39.46486860562311
# Episode 101: PDE Error: 0.185380766213; False Transient Error: 0.182210480969; Iterations: 339; CG Error: 0.000000000100
# min ems: 0.011492349409502733
# min mc 39.47154518786037
# Episode 102: PDE Error: 0.182169928071; False Transient Error: 0.179024421754; Iterations: 337; CG Error: 0.000000000094
# min ems: 0.011496638276188605
# min mc 39.47826953796184
# Episode 103: PDE Error: 0.178987367861; False Transient Error: 0.175869309152; Iterations: 333; CG Error: 0.000000000098
# min ems: 0.011500761372501212
# min mc 39.48496362621543
# Episode 104: PDE Error: 0.175838681255; False Transient Error: 0.172747284751; Iterations: 329; CG Error: 0.000000000096
# min ems: 0.011504726109342172
# min mc 39.49170687480598
# Episode 105: PDE Error: 0.172734646285; False Transient Error: 0.169660213531; Iterations: 327; CG Error: 0.000000000097
# min ems: 0.011508539540121387
# min mc 39.498466122177156
# Episode 106: PDE Error: 0.169701080337; False Transient Error: 0.166609634463; Iterations: 322; CG Error: 0.000000000099
# min ems: 0.011512208378434167
# min mc 39.50513146114647
# Episode 107: PDE Error: 0.166724878443; False Transient Error: 0.163596898387; Iterations: 320; CG Error: 0.000000000098
# min ems: 0.011515739015029216
# min mc 39.490504413149026
# Episode 108: PDE Error: 0.163801317876; False Transient Error: 0.160623119335; Iterations: 320; CG Error: 0.000000000099
# min ems: 0.011519137534202525
# min mc 39.46833532005193
# Episode 109: PDE Error: 0.160928756903; False Transient Error: 0.157689146005; Iterations: 316; CG Error: 0.000000000095
# min ems: 0.011522409728712423
# min mc 39.44645871378672
# Episode 110: PDE Error: 0.158106342519; False Transient Error: 0.154795717303; Iterations: 315; CG Error: 0.000000000097
# min ems: 0.01152556111447432
# min mc 39.424951286376604
# Episode 111: PDE Error: 0.155334042767; False Transient Error: 0.151943352510; Iterations: 312; CG Error: 0.000000000096
# min ems: 0.011528596944092903
# min mc 39.40387515531537
# Episode 112: PDE Error: 0.152612935518; False Transient Error: 0.149140949270; Iterations: 310; CG Error: 0.000000000094
# min ems: 0.011531522220033324
# min mc 39.38327937937251
# Episode 113: PDE Error: 0.149942833594; False Transient Error: 0.146397707249; Iterations: 307; CG Error: 0.000000000099
# min ems: 0.011534341707180483
# min mc 39.36320146122635
# Episode 114: PDE Error: 0.147309752490; False Transient Error: 0.143706330673; Iterations: 305; CG Error: 0.000000000100
# min ems: 0.011537059944369828
# min mc 39.343668800682366
# Episode 115: PDE Error: 0.144704829168; False Transient Error: 0.141063643789; Iterations: 304; CG Error: 0.000000000094
# min ems: 0.011539681256064176
# min mc 39.32470002028333
# Episode 116: PDE Error: 0.142127481194; False Transient Error: 0.138467982098; Iterations: 302; CG Error: 0.000000000096
# min ems: 0.011542209762515491
# min mc 39.30630621107289
# Episode 117: PDE Error: 0.139579652675; False Transient Error: 0.135918176968; Iterations: 301; CG Error: 0.000000000092
# min ems: 0.011544649390236318
# min mc 39.288492093306864
# Episode 118: PDE Error: 0.137060964923; False Transient Error: 0.133413472490; Iterations: 299; CG Error: 0.000000000096
# min ems: 0.011547003881629525
# min mc 39.271063519041526
# Episode 119: PDE Error: 0.134572793254; False Transient Error: 0.130953010066; Iterations: 298; CG Error: 0.000000000099
# min ems: 0.01154927680379993
# min mc 39.2542047605928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-269-274ccaa60145> in <module>
#      90     print("min mc", np.min(mc_new))
#      91     # HJB coefficient
# ---> 92     entropy = np.sum(πa*(np.log(πa) - np.log(πa_o)), axis=0)
#      93     A =  -δ*np.ones(y_mat.shape)
#      94     B_y = np.sum(θ_mat*πa, axis=0)*ems_new
#
# KeyboardInterrupt:

# %%
plt.hist(θ_list*1000, weights=πa[:,-1,-1])
plt.hist(θ_list*1000, weights=πa_o[:, 0, 0], alpha=0.3)
# Out:
# (array([0.05555556, 0.08333333, 0.13194444, 0.13888889, 0.11805556,
#         0.20138889, 0.10416667, 0.07638889, 0.0625    , 0.02777778]),
#  array([1.0154  , 1.194787, 1.374174, 1.553561, 1.732948, 1.912335,
#         2.091722, 2.271109, 2.450496, 2.629883, 2.80927 ]),
#  <BarContainer object of 10 artists>)

# %%
loc1 = np.abs(np.exp(k_grid) - 700).argmin()
plt.plot(y_grid, v0[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, v0[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'$\phi(log(K), y), \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('ϕ_new.png', dpi=300)
plt.show()

# %%
plt.plot(1 -  ems_new/(α*λ_bar*np.exp(k_mat)))
plt.show()

# %%
# plt.plot(y_grid, ems[:, -1])
plt.plot(y_grid, ems[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ems[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'Emission, $\gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('emission_01.png', dpi=300)
# plt.ylim(0,12)
# Out:
# Text(0.5, 0, 'y')

# %%
y_grid[-50], y_mat.shape
# Out:
# (1.55, (81, 208))

# %%
plt.plot(k_grid, ems[-1], label="y = 4")
plt.xlabel("$\log K$")
plt.legend()
plt.savefig('e_logk.png')

# %%
np.exp(7), y_grid[40]
# Out:
# (1096.6331584284585, 2.0)

# %%
plt.plot(np.exp(k_grid), ems[40], label = "y = 2")
plt.plot(np.exp(k_grid), ems[-1], label = "y = 4")
plt.legend()
plt.xlabel('K')
plt.title('Emission')
# plt.savefig('emission_k_9.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Emission')

# %%
plt.plot(k_grid, ems[40], label = "y = 2")
plt.plot(k_grid, ems[-1], label = "y = 4")
plt.legend()
plt.xlabel('$\log K$')
plt.title('Emission')
# plt.savefig('emission_k_9.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Emission')

# %%
iota = 1 - ems/np.exp(k_mat)/α/λ_bar
plt.plot(y_grid, iota[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, iota[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'ι(y), $\gamma_3 = 0$, with fixed $\bar \lambda$')
plt.xlabel('y')
# plt.savefig('iota_01.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
ra = α*ϑ_bar*iota**θ
plt.plot(y_grid, ra[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ra[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'$\frac{X}{K}, \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('XK_new.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
ra = ems/np.exp(k_mat)/α
plt.plot(y_grid, ra[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ra[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'$\frac{E}{\alpha K}, \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('ratio_01.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
# simulate
def simulate_logkapital(invkap, αₖ,  σₖ, κ, k0, T=100, dt=1):
    periods = int(T/dt)
    Kt = np.zeros(periods)
    i = invkap
     # log capital
    Kt[0] = np.log(k0)
    k = np.log(k0)
    for t in range(periods-1):
        k +=   (αₖ + i - κ/2*i**2 - .5*σₖ**2)*dt
        Kt[t+1] = k
    return Kt

# %%
n_temp = 16
n_carb = 9
n_θ = len(θ_list)
θ_mat = θ_list.reshape(n_temp, n_carb)
θtemp_list = np.average(θ_mat, axis=1)
θcarb_list = np.average(θ_mat, axis=0)

# %% [markdown]
# # Simulation
#
# ??:
#
# $$
# ME_t = \vartheta_t \theta \frac{1}{\lambda_t} \left[1 -  \frac{\mathcal{E}_t}{\alpha \lambda_t K_t }\right]^{\theta - 1}
# $$

# %%
class GridInterp_2d():

    def __init__(self, grids, values, method = 'Linear'):

        # unpacking
        self.grids = grids
        (self.xs, self.ys) = grids
        self.nx = len(self.xs)
        self.ny = len(self.ys)
        
        self.values = values

        assert (self.nx, self.ny) == values.shape, "ValueError: Dimensions not match"
        self.method = method

    def get_value(self, x, y):

        if self.method == 'Linear':
            
            func = RegularGridInterpolator(self.grids, self.values)
            return func([x,y])[0]

        elif self.method == 'Spline':

            func1 = CubicSpline(self.xs, self.values)
            ySpace = func1(x)
            
            func2 = CubicSpline(self.ys, ySpace)
            return func2(y)

        else:
            raise ValueError('Method Not Supported')

# %%
plt.plot(y_grid, i)
plt.show()

# %%
Time = 90
ppy = 12
pers = ppy * Time
# pers = 100
dt = Time / pers
nDims = 3 
its = 1

gridpoints = (y_grid, k_grid)
# interpolate emission
e_func_r = GridInterp_2d(gridpoints, ems, 'Linear')
def e_func(x):
    return e_func_r.get_value(x[0], x[1]) # match order
# interpolate investment
i_func_r = GridInterp_2d(gridpoints, i, 'Linear')
def i_func(x):
    return i_func_r.get_value(x[0], x[1])

# drifts for each diffusion process
def compute_μlogk(x):
    return μk +  i_func(x)  - 0.5*κ*i_func(x)**2 - 0.5*σk**2
def compute_μy(E_x):
    return  E_x*np.mean(θ_list)
def compute_μlogd(x, E_x):
    Y_x = x[0]
    dΛ = γ1 + γ2*Y_x + γ3*(Y_x - y_bar)*(Y_x >y_bar)
    ddΛ = γ2 + γ3*(Y_x > y_bar)  
    return dΛ*compute_μy(E_x) + 0.5*ddΛ*σy**2*E_x**2

# initial points

K_0 = 80/α
Y_0 = 1.1
D_0 = np.exp(γ1*Y_0 + γ2*Y_0**2 + γ3*((Y_0 - y_bar)**2)*(Y_0 >y_bar))-1
          
# stop
hist = np.zeros([pers, nDims])
e_hist = np.zeros([pers])
i_hist = np.zeros([pers])

for tm in range(pers):
    if tm == 0:
        # initial points
        hist[0,:] = [Y_0, np.log(K_0), D_0]
        e_hist[0] = e_func(hist[0,:])
        i_hist[0] = i_func(hist[0,:])

    else:
        # other periods
        hist[tm,0] = hist[tm - 1,0] + compute_μy(e_hist[tm-1])*dt# Y
        hist[tm,1] = hist[tm - 1,1] + compute_μlogk(hist[tm-1,:])*dt# logK
        hist[tm,2] = hist[tm - 1,2] + compute_μlogd(hist[tm-1,:], e_hist[tm-1])*dt # logDt
        e_hist[tm] = e_func(hist[tm,:])
        i_hist[tm] = i_func(hist[tm,:])

e_k_ratio = e_hist/np.exp(hist[:,1])/α
Iota_t = 1 - e_hist/np.exp(hist[:,1])/(α*λ_bar)
XK_t = α*θ_bar*Iota_t**θ
MUe = θ*θ_bar/λ_bar*Iota_t**(θ-1)

simul = dict(e= e_hist, states= hist)

# %%
plt.plot(np.arange(0, Time, dt), e_hist)
plt.xlabel('Years')
# plt.savefig('Et.png')
# Out:
# Text(0.5, 0, 'Years')

# %%
plt.plot(np.arange(0, Time, dt), e_k_ratio)
plt.xlabel('Years')
plt.title(r'$\frac{E_t}{\alpha K_t}$')
# plt.savefig('ratio.png')
# Out:
# Text(0.5, 1.0, '$\\frac{E_t}{\\alpha K_t}$')

# %%
plt.plot(np.arange(0, Time, dt), Iota_t)
plt.xlabel('Years')
plt.title(r"$\iota_t$")
# plt.savefig('iota_t.png')
# Out:
# Text(0.5, 1.0, '$\\iota_t$')

# %%
hist[480],e_hist[480]
# Out:
# (array([2.11951791, 7.30149649, 0.00748107]), 17.711169968365482)

# %%
plt.plot(hist[:,0])

# %%
plt.plot(simul['states'][:, 1])

# %%
plt.plot(simul['e'])
