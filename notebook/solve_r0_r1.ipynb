# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y_upper_bar = 2.
y_lower_bar = 1.7

# Solve r1
r1_grid = np.linspace(-54.16694, -54.1669 , 100)
plt.plot(r1_grid, np.exp(r1_grid/2 * (y_upper_bar - y_lower_bar)**2) + 1)
plt.plot(r1_grid, 2 * np.exp(r1_grid/2 * ((y_upper_bar+y_lower_bar)/2 - y_lower_bar)**2))

# %%
# -4.3830 * (np.exp(-54.1669/2 * (y_upper_bar - y_lower_bar)**2) - 1)
-1.0957 * (np.exp(-54.1669/2 * (y_upper_bar - y_lower_bar)**2) - 1)
# Out:
# 0.9999598062749897

# %%
def intensity(y, y_lower_bar=1.7, y_upper_bar=2.0):
    r0 = -5.7239
    r1 = -8.125
    res = r0*(np.exp(r1/2*(y-y_lower_bar)**2) - 1) * (y >= y_lower_bar)\
          + 0 * (y < y_lower_bar)
    return res

# %%
y_grid = np.linspace(0, 2, 100)
plt.plot(y_grid, intensity(y_grid))

# %%
intensity(y_grid)[92]
# Out:
# 0.5559264372075056

# %%
term_1 = np.exp(r1/2*(y_upper_bar-y_lower_bar)**2) - 1
term_2 = np.exp(r1/2*(y_upper_ba))
