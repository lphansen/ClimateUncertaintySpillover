# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()) + '/source')

from experiment import solve_value_function, solve_alternative_ME
from model import ode_y, ode_y_jump_approach_one_boundary, uncertainty_decomposition
from simulation import simulation
from utilities import find_nearest_value
from numba import njit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
# Simulate capital process
# Capital and z parameters
α_k = -0.043
β_k = 0.04
σ_k = np.array([0.477*2, 0])/100.
β_z = 0.014*4
σ_z = np.array([0.011*2, 0.025*2])
α = 0.115
ioverk = 0.09
κ = 6.667


@njit(parallel=True)
def simulate_capital(α_k, β_k, σ_k, β_z, σ_z, ioverk, κ, Ws, k_start, N=100_000, T=100, dt=1.):
    var_z = dt*σ_z@σ_z/(1-(1-β_z*dt)**2)
    std_z = np.sqrt(var_z)

    time_periods = int(T/dt)
    z_path = np.zeros((N, time_periods+1))
    k_path = np.zeros((N, time_periods+1))
    for i in range(N):
        z0 = np.random.normal(0.,std_z)
        k0 = k_start
        z_path[i, 0] = z0
        k_path[i, 0] = k0
        for j in range(1, time_periods+1):
            k1 = k0 + (α_k + β_k*z0 + ioverk - κ/2.*ioverk**2 - σ_k@σ_k/2.)*dt + σ_k@Ws[i, j]*np.sqrt(dt)
            z1 = (1.-β_z*dt)*z0 + σ_z@Ws[i, j]*np.sqrt(dt)
            k_path[i, j] = k1
            z_path[i, j] = z1
            k0 = k1
            z0 = z1
    return k_path

T = 100
N = 1_000_000
dt = 1.
k_start = np.log(80/α)
η = .032
Ws = np.random.multivariate_normal(np.zeros(2), np.eye(2), (N, int(T/dt)))
logk_path = simulate_capital(α_k, β_k, σ_k, β_z, σ_z, ioverk, κ, Ws, k_start, N=N, T=T, dt=dt)
Kt = np.percentile(np.exp(logk_path), 50, axis=0)

# %% [markdown]
# ## SCC and Uncertainty

# %%
ξ_w = .3
ξ_p = 5.
ξ_a = 100000.

n_model = 40
damage_setting={'γ_2p': np.linspace(0, 1./3, n_model),
                'πd_o': np.ones(n_model)/n_model}

ϵ = 5.
η = .032
δ = .01

θ = pd.read_csv('../data/model144.csv', header=None).to_numpy()[:, 0]/1000.
πc_o = np.ones_like(θ)/len(θ)

σ_y = 1.2*np.mean(θ)
y_bar = 1.9
γ_1 = 1.7675/10000
γ_2 = .0022*2
γ_2p = damage_setting['γ_2p']
πd_o = damage_setting['πd_o']

y_step = .02
y_grid_long = np.arange(0., y_bar*2, y_step)
y_grid_short = np.arange(0., y_bar+y_step, y_step)
n_bar = find_nearest_value(y_grid_long, y_bar) + 1

# Uncertainty decomposition
n_temp = 16
n_carb = 9
θ_reshape = θ.reshape(n_temp, n_carb)
θ_temp = np.mean(θ_reshape, axis=1)
θ_carb = np.mean(θ_reshape, axis=0)
πc_o_temp = np.ones_like(θ_temp)/len(θ_temp)
πc_o_carb = np.ones_like(θ_carb)/len(θ_carb)

# Prepare ϕ_i (carbon + temperature)
ϕ_list = []
for i, γ_2p_i in enumerate(γ_2p):
    print(i)
    model_paras = (η, δ, θ, πc_o, σ_y, ξ_w, ξ_a, γ_1, γ_2, γ_2p_i, y_bar) 
    model_res = ode_y(y_grid_long, model_paras, v0=None, ϵ=ϵ,
                       tol=1e-8, max_iter=1_000, print_all=False)
    ϕ_list.append(model_res['v0'])

ϕ_list_short = []
for ϕ_i in ϕ_list:
    temp = ϕ_i[:n_bar]
    ϕ_list_short.append(temp)
ϕ_i_carb_temp = np.array(ϕ_list_short)

# Prepare ϕ_i (baseline)
ϕ_list = []
for i, γ_2p_i in enumerate(γ_2p):
    print(i)
    model_paras = (η, δ, θ, πc_o, σ_y, ξ_w, 1000., γ_1, γ_2, γ_2p_i, y_bar) 
    model_res = ode_y(y_grid_long, model_paras, v0=None, ϵ=ϵ,
                       tol=1e-8, max_iter=1_000, print_all=False)
    ϕ_list.append(model_res['v0'])

ϕ_list_short = []
for ϕ_i in ϕ_list:
    temp = ϕ_i[:n_bar]
    ϕ_list_short.append(temp)
ϕ_i_baseline = np.array(ϕ_list_short)

# Compute ϕ
ς = .25
model_paras = (η, δ, θ, πc_o, σ_y, ξ_w, ξ_p, ξ_a, ς, γ_1, γ_2, y_bar, ϕ_i_carb_temp, πd_o)
model_res = ode_y_jump_approach_one_boundary(y_grid_short, model_paras, 
                                             v0=np.average(ϕ_i_carb_temp, weights=πd_o, axis=0),
                                             ϵ=ϵ, tol=1e-8, max_iter=2_000, print_all=False)

ME_total = η/model_res['e_tilde']

# Solve baseline
model_paras_new = (η, δ, θ, πc_o, σ_y, ξ_w, ξ_p, ξ_a, γ_1, γ_2, ϕ_i_baseline, πd_o)
model_res_new = uncertainty_decomposition(y_grid_short, model_paras_new,
                                          e_tilde=model_res['e_tilde'], 
                                          h=np.zeros_like(model_res['h']),
                                          πc=np.ones_like(model_res['πc'])/len(θ),
                                          bc=np.average(ϕ_i_baseline, weights=πd_o, axis=0)[-1],
                                          v0=None, ϵ=ϵ, tol=1e-8, max_iter=2_000, print_all=False)  
ME_baseline = model_res_new['ME']
# Out:
# 0
# Converged. Total iteration 1000: LHS Error: 9.803805037300606e-06; RHS Error 0.00014178582723228805
# 1
# Converged. Total iteration 1000: LHS Error: 1.2462844170180177e-05; RHS Error 0.0001266114222378753
# 2
# Converged. Total iteration 1000: LHS Error: 9.323832550034439e-06; RHS Error 0.00021307710326111395
# 3
# Converged. Total iteration 1000: LHS Error: 7.867022342278317e-06; RHS Error 0.00028458812640508313
# 4
# Converged. Total iteration 1000: LHS Error: 8.786323749454539e-06; RHS Error 0.0003463592993045578
# 5
# Converged. Total iteration 1000: LHS Error: 1.0297548037829785e-05; RHS Error 0.00040265185544737653
# 6
# Converged. Total iteration 1000: LHS Error: 1.2391331421568453e-05; RHS Error 0.0004496616934954595
# 7
# Converged. Total iteration 1000: LHS Error: 1.1957210321700273e-05; RHS Error 0.0004932739569898578
# 8
# Converged. Total iteration 1000: LHS Error: 8.557054259750174e-06; RHS Error 0.0005298696190591048
# 9
# Converged. Total iteration 1000: LHS Error: 1.5094207663368663e-05; RHS Error 0.000572304257265982
# 10
# Converged. Total iteration 1000: LHS Error: 2.290061699570245e-05; RHS Error 0.0006060025585907687
# 11
# Converged. Total iteration 1000: LHS Error: 5.446769286243658e-06; RHS Error 0.0006399936779288018
# 12
# Converged. Total iteration 1000: LHS Error: 1.3749215100022915e-05; RHS Error 0.0006707501225081472
# 13
# Converged. Total iteration 1000: LHS Error: 9.158283441479398e-06; RHS Error 0.0006983778015999115
# 14
# Converged. Total iteration 1000: LHS Error: 5.417136827090552e-06; RHS Error 0.000727511947013617
# 15
# Converged. Total iteration 1000: LHS Error: 1.3529377415921751e-05; RHS Error 0.0007570257753662969
# 16
# Converged. Total iteration 1000: LHS Error: 2.3795874244059156e-05; RHS Error 0.000785539700339774
# 17
# Converged. Total iteration 1000: LHS Error: 1.3562890823282104e-05; RHS Error 0.0008102499881203346
# 18
# Converged. Total iteration 1000: LHS Error: 1.6787470396079084e-05; RHS Error 0.000826313301912223
# 19
# Converged. Total iteration 1000: LHS Error: 1.097830352823348e-05; RHS Error 0.000862526630051156
# 20
# Converged. Total iteration 1000: LHS Error: 8.954170414887664e-06; RHS Error 0.0008702284081856179
# 21
# Converged. Total iteration 1000: LHS Error: 1.2358332929085502e-05; RHS Error 0.0009072310788723718
# 22
# Converged. Total iteration 1000: LHS Error: 9.891170340403655e-06; RHS Error 0.0009403865247417861
# 23
# Converged. Total iteration 1000: LHS Error: 1.2662210296318643e-05; RHS Error 0.0009547178032156718
# 24
# Converged. Total iteration 1000: LHS Error: 1.4043858326026615e-05; RHS Error 0.0009898725870377857
# 25
# Converged. Total iteration 1000: LHS Error: 1.657072918461733e-05; RHS Error 0.0010115205012840058
# 26
# Converged. Total iteration 1000: LHS Error: 7.623390880706627e-06; RHS Error 0.0010167522290028992
# 27
# Converged. Total iteration 1000: LHS Error: 5.906004815234289e-06; RHS Error 0.0010541906642345701
# 28
# Converged. Total iteration 1000: LHS Error: 5.2821251827739334e-05; RHS Error 0.0010408312174451893
# 29
# Converged. Total iteration 1000: LHS Error: 3.4137686753055176e-05; RHS Error 0.0010654578157274289
# 30
# Converged. Total iteration 1000: LHS Error: 1.7136443835646942e-05; RHS Error 0.001083914735668455
# 31
# Converged. Total iteration 1000: LHS Error: 2.5534543477467863e-05; RHS Error 0.0011312456540405469
# 32
# Converged. Total iteration 1000: LHS Error: 2.3967227969379223e-05; RHS Error 0.0011254443570674587
# 33
# Converged. Total iteration 1000: LHS Error: 4.9638519541672645e-05; RHS Error 0.0011281740355025723
# 34
# Converged. Total iteration 1000: LHS Error: 1.0623579123980597e-05; RHS Error 0.0011537997249256235
# 35
# Converged. Total iteration 1000: LHS Error: 2.794733945195027e-05; RHS Error 0.0011613104133578502
# 36
# Converged. Total iteration 1000: LHS Error: 4.2739869817021156e-05; RHS Error 0.001184656888453494
# 37
# Converged. Total iteration 1000: LHS Error: 1.2856220482060366e-05; RHS Error 0.0012292244428514301
# 38
# Converged. Total iteration 1000: LHS Error: 2.518497115739926e-05; RHS Error 0.001239125755757348
# 39
# Converged. Total iteration 1000: LHS Error: 1.9555485829347853e-05; RHS Error 0.0012650948732673556
# 0
# Converged. Total iteration 1000: LHS Error: 2.7188007266154558e-05; RHS Error 8.608967465631445e-05
# 1
# Converged. Total iteration 1000: LHS Error: 1.017859464189641e-05; RHS Error 0.00013212356226922906
# 2
# Converged. Total iteration 1000: LHS Error: 5.242386501080887e-06; RHS Error 0.0002134244028909535
# 3
# Converged. Total iteration 1000: LHS Error: 1.090648044650422e-05; RHS Error 0.000284296689395544
# 4
# Converged. Total iteration 1000: LHS Error: 1.308405855793282e-05; RHS Error 0.00034524237816525166
# 5
# Converged. Total iteration 1000: LHS Error: 8.815262919092958e-06; RHS Error 0.0003988644509773792
# 6
# Converged. Total iteration 1000: LHS Error: 1.3924002472531783e-05; RHS Error 0.00044902007356931173
# 7
# Converged. Total iteration 1000: LHS Error: 4.8137920497293155e-06; RHS Error 0.00049254284316258
# 8
# Converged. Total iteration 1000: LHS Error: 1.4789385065716587e-05; RHS Error 0.0005307486177686602
# 9
# Converged. Total iteration 1000: LHS Error: 7.855799684630682e-06; RHS Error 0.0005705423215863759
# 10
# Converged. Total iteration 1000: LHS Error: 7.82954451428175e-06; RHS Error 0.0006057052137758284
# 11
# Converged. Total iteration 1000: LHS Error: 1.9816813920714438e-05; RHS Error 0.0006399293994071263
# 12
# Converged. Total iteration 1000: LHS Error: 1.797023405281095e-06; RHS Error 0.0006694200993717127
# 13
# Converged. Total iteration 1000: LHS Error: 5.268064788133131e-06; RHS Error 0.0006990002734308942
# 14
# Converged. Total iteration 1000: LHS Error: 1.7194213476945385e-05; RHS Error 0.0007263155692386371
# 15
# Converged. Total iteration 1000: LHS Error: 8.104701490685429e-06; RHS Error 0.000755379119743594
# 16
# Converged. Total iteration 1000: LHS Error: 3.306049984064252e-06; RHS Error 0.0007831163001002645
# 17
# Converged. Total iteration 1000: LHS Error: 4.5708636484231844e-06; RHS Error 0.0008091909206239603
# 18
# Converged. Total iteration 1000: LHS Error: 1.8227315169738743e-05; RHS Error 0.0008315876363778826
# 19
# Converged. Total iteration 1000: LHS Error: 7.203323462245948e-06; RHS Error 0.0008573547754896563
# 20
# Converged. Total iteration 1000: LHS Error: 9.639693595586696e-06; RHS Error 0.0008731662582262371
# 21
# Converged. Total iteration 1000: LHS Error: 2.7891577932925847e-06; RHS Error 0.0009194320790490464
# 22
# Converged. Total iteration 1000: LHS Error: 8.78606242303015e-06; RHS Error 0.000939976791788772
# 23
# Converged. Total iteration 1000: LHS Error: 1.2705192959247547e-05; RHS Error 0.0009557358486047517
# 24
# Converged. Total iteration 1000: LHS Error: 7.6271317636877886e-06; RHS Error 0.0009914963880816793
# 25
# Converged. Total iteration 1000: LHS Error: 1.3119262741217996e-05; RHS Error 0.0010028114484045524
# 26
# Converged. Total iteration 1000: LHS Error: 1.8368668111901077e-05; RHS Error 0.0010253545207724243
# 27
# Converged. Total iteration 1000: LHS Error: 0.11679097130943461; RHS Error 0.16866255623283805
# 28
# Converged. Total iteration 1000: LHS Error: 3.008890060787195e-05; RHS Error 0.0010565199591287752
# 29
# Converged. Total iteration 1000: LHS Error: 2.832504250960266e-05; RHS Error 0.0010918428380256723
# 30
# Converged. Total iteration 1000: LHS Error: 6.293470440910109e-06; RHS Error 0.0011008300792111486
# 31
# Converged. Total iteration 1000: LHS Error: 1.416523916771828e-05; RHS Error 0.0011069746287828836
# 32
# Converged. Total iteration 1000: LHS Error: 1.4623106465716517e-07; RHS Error 0.0011320985122411469
# 33
# Converged. Total iteration 569: LHS Error: 7.699988824327874e-09; RHS Error 0.0011489202791345222
# 34
# Converged. Total iteration 1000: LHS Error: 9.460616767764662e-08; RHS Error 0.001165270219971936
# 35
# Converged. Total iteration 377: LHS Error: 9.64680541559737e-09; RHS Error 0.0011814662990263618
# 36
# Converged. Total iteration 1000: LHS Error: 2.0755175444975293e-07; RHS Error 0.001197223002221819
# 37
# Converged. Total iteration 1000: LHS Error: 6.199304325438248e-08; RHS Error 0.0012126124776606732
# 38
# Converged. Total iteration 591: LHS Error: 7.595128237447569e-09; RHS Error 0.001227735679387337
# 39
# Converged. Total iteration 762: LHS Error: 7.333333806869291e-09; RHS Error 0.0012425949845206365
# Converged. Total iteration 2000: LHS Error: 2.1556142841605563e-06; RHS Error 0.000835351444779274
# Converged. Total iteration 2000: LHS Error: 1.6675257559217727e-06; RHS Error 0.00086513789936336

# %%
y_grid_short.shape
# Out:
# (96,)

# %%
def simulation_me(y_grid, e_grid, ratio_grid, θ=1.86/1000., y_start=.5394, T=50):
    Et = np.zeros(T+1)
    yt = np.zeros(T+1)
    ratio_t = np.zeros(T+1)
    for i in range(T+1):
        Et[i] = np.interp(y_start, y_grid, e_grid)
        ratio_t[i] = np.interp(y_start, y_grid, ratio_grid)
        yt[i] = y_start
        y_start = y_start + Et[i]*θ
    return Et, yt, ratio_t

et, yt, ht, gt = simulation(model_res['y_grid'], model_res['e_tilde'], model_res['h'], model_res['g'],
                            θ=np.mean(model_res['θ']), y_start=1.1, T=80)

_, _, ratio_t = simulation_me(y_grid_short, model_res['e_tilde'], 
                                      ME_baseline/ME_total, θ=np.mean(θ), y_start=1.1, T=80)

# %%
SCCt_all = η*(0.025)*Kt[:81]/((1.-η)*et) * 1000
SCCt_baseline = SCCt_all * ratio_t
SCCt_uncertainty = SCCt_all - SCCt_baseline

plt.figure(figsize=(8, 5))
plt.plot(SCCt_all, color='rebeccapurple', label='Total', linewidth=2.5)
plt.plot(SCCt_uncertainty, color='rebeccapurple', label='Uncertainty', linestyle='dashed', linewidth=2.5)
plt.fill_between(np.arange(0, 81, 1), np.zeros_like(SCCt_uncertainty), 
                 SCCt_uncertainty, color='rebeccapurple', alpha=.4)
plt.ylim(0, 1000)
plt.xlim(0, 80)
plt.xlabel('Years', fontsize=13)
plt.ylabel('SCC ($/tC)', fontsize=13)
plt.legend(frameon=False, loc='upper left')
plt.savefig('../plots/scc_two.pdf')

# %%
πd_T = gt[:, -1] * damage_setting['πd_o'] / (gt[:, -1]@damage_setting['πd_o'])

plt.hist(damage_setting['γ_2p'], weights=πd_T, density=False, bins=40)
plt.xlabel(r'$\gamma_3$', fontsize=13)
plt.ylabel('Probability', fontsize=13)
plt.savefig('../plots/damage_prob_two.pdf')
