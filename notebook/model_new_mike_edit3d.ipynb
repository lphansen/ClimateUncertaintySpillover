# %%
# packages
import numpy as np
import pandas as pd
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()) + '/source')
import pickle
from solver_1d import false_transient_one_iteration_python
from supportfunctions import PDESolver_2d, finiteDiff
from numba import njit
from scipy.sparse import csc_matrix
from scipy.sparse.linalg import bicg
import SolveLinSys
import time
from derivative import derivatives_2d
from solver_ode import solve_ode, solve_ode_one, derivative_1d, solve_ode_neumann
from solver_jump import approach_one_100, solve_smooth_100, solve_jump_100
from scipy import interpolate
import matplotlib.pyplot as plt
import matplotlib as mpl
import time
import matplotlib.transforms as transforms
from scipy.interpolate import RegularGridInterpolator, CubicSpline
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['figure.facecolor'] = 'w'
mpl.rcParams['figure.edgecolor'] = 'w'

# %%
# parameters
δ = 0.01
η = 0.032
μ = 1.86/1000
θ_list = pd.read_csv("../data/model144.csv", header=None)[0].to_numpy()
θ_list = θ_list/1000
σy = 1.2*np.mean(θ_list)
# damage function
ȳ = 2
γ1 = 0.00017675
γ2 = 2*0.0022
# γ3_list = np.linspace(0, 1/3, 40)
# γ3_list = np.array([0, 0.0197*2, 0.3853*2])
γ3_list = np.array([0, 0.0197*2, 1/3])
# γ3_list[0] = 0

dmg_weight = np.ones(len(γ3_list))/len(γ3_list)
# capital parameters
invkap = 0.09
α = 0.115
μk = - 0.043
σk = 0.0085
κ = 6.667
k0 = 80/α

# %%
numy_bar = 50
y_min = 0
y_max = 4
hy = (ȳ - y_min)/numy_bar
y_grid = np.arange(y_min, y_max+hy, hy)

# y_step = 0.05
# y_grid = np.arange(0., 4 + y_step, y_step)

k_step = 0.1
k_grid = np.arange(0., 9 + k_step, k_step)

(y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
hy = y_grid[1] - y_grid[0]
hk = k_grid[1] - k_grid[0]
n_y = len(y_grid)
n_k = len(k_grid)

# %%
y_mat.shape
# Out:
# (101, 91)

# %%
def solve_new(y_grid, k_grid, args, ϵ=0.5, max_iter=2000, tol=1e-6):
    δ, η, α, μk, σk, κ, θ, θ_list, σy, γ1, γ2, γ3, y_bar, ξa, ϑ_bar, λ_bar = args
    n_y = len(y_grid)
    n_k = len(k_grid)
    dy = y_grid[1] - y_grid[0]
    dk = k_grid[1] - k_grid[0]
    (y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
    stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
    πa_o = np.ones((len(θ_list), n_y, n_k))/len(θ_list)
    θ_mat = np.zeros((len(θ_list), n_y, n_k))
    for i in range(len(θ_list)):
        θ_mat[i] = θ_list[i]
    πa = πa_o
    
    dΛ = γ1 + γ2*y_mat + γ3*(y_mat - y_bar)*(y_mat >y_bar)
    ddΛ = γ2 + γ3*(y_mat > y_bar)
    v0 =  -  η*y_mat**2 + k_mat**2
    ems_new = η*y_mat**2 + k_mat**2
    ems_old = ems_new
    episode = 0
    lhs_error = 0.5
    vd = - 1/δ
    while lhs_error > tol:
        if episode ==0:
            i = 0
            ems = ems_new
            mc_new = 1/(α - i - np.exp(ϑ_bar)*(1 - np.exp(λ_bar)*(ems/np.exp(k_mat))**θ) )
        else:
            vold = v0.copy()
        v0_dy = derivatives_2d(v0,0,1,dy)
        v0_dyy = derivatives_2d(v0,0,2,dy)
        v0_dk = derivatives_2d(v0,1,1,dk)
#         v0_dy2[v0_dy2 > - 1e-15] =  - 1e-15
        v0_dkk = derivatives_2d(v0,1,2,dk)
        # updating controls
        mc = mc_new
        i_new = 1 - mc/v0_dk
        # update emission
        a = v0_dyy*σy**2 + vd*ddΛ*σy**2 - mc*θ*np.exp(ϑ_bar)*np.exp(2*(λ_bar-k_mat))
        b = mc*θ*np.exp(ϑ_bar + λ_bar - k_mat) + v0_dy*np.sum(θ_mat*πa, axis=0) \
            + vd*dΛ*np.sum(θ_mat*πa, axis=0)
        ems_new = -b/a
        ems_new[ems_new < 1e-15] = 1e-15
        mc_new = 1/(α - i_new - np.exp(ϑ_bar)*(1 - np.exp(λ_bar)*(ems_new/np.exp(k_mat))**θ) )
#         ems_new[ems_new <= 1e-15] = 1e-15
#         ems = ems_new*0.5 + ems_old*0.5

#         weight = np.array([-1/ξa*v0_dy2*λ*ems*θ for θ in θ_list])
#         weight = weight - np.max(weight, axis=0)
#         πa = πa_o*np.exp(weight)
#         πa[πa<1e-15] = 1e-15
#         πa = πa/np.sum(πa, axis=0)
        print(np.min(ems_new))
        # HJB coefficient
        entropy = np.sum(πa*(np.log(πa) - np.log(πa_o)), axis=0)
        A =  -δ*np.ones(y_mat.shape)
        B_y = np.sum(θ_mat*πa, axis=0)*ems
        B_k = μk + i_new - 0.5*κ*i_new**2 - 0.5*σk**2
        C_yy = 0.5*ems**2*σy**2
        C_kk = 0.5*σk**2*np.ones(y_mat.shape)
        D = np.log(mc_new) + k_mat + vd*(dΛ*np.sum(θ_mat*πa, axis=0)*ems_new + 0.5*ddΛ*σy**2*ems_new**2) \
            + ξa*entropy
        # PDE solver
        out = PDESolver_2d(stateSpace, A, B_y, B_k, C_yy, C_kk, D, v0, ϵ, solverType = 'False Transient')
        out_comp = out[2].reshape(v0.shape,order = "F")
        rhs = A*v0 + B_y*v0_dy + B_k*v0_dk + C_yy*v0_dyy + C_kk*v0_dkk  + D
        rhs_error = np.max(abs(rhs))
        lhs_error = np.max(abs((out_comp - v0)/ϵ))
        #     if episode % 1 == 0:
        print("Episode {:d}: PDE Error: {:.12f}; False Transient Error: {:.12f}; Iterations: {:d}; CG Error: {:.12f}".format(episode, rhs_error, lhs_error, out[0], out[1]))
        episode += 1
        v0 = out_comp
        ems_old = ems_new
    result = dict(v0=v0, ems=ems, πa=πa)
    return result

# %% [markdown]
# $$
# mc = \frac{1}{\alpha - i - \alpha \vartheta (1 - \frac{e}{\alpha \lambda  \exp(k)})^\theta}
# $$
#
# First order condition for $i$:
#
# $$
#  - mc + \frac{d\phi}{dk} (1 - \kappa i) = 0
# $$
#
# FOC for $e$:
#
# $$
# mc (\bar{\vartheta} \theta \frac{1 }{\lambda \exp (k)}  (1 - \frac{e}{\alpha \lambda \exp{k}})^{\theta - 1}) +
# $$

# %%
# HJB for ϕ_m
# θ = 2
θ = 3
y_bar = 2
ξa = 0.01
# ξa = 10000
# ξb = 3
ξb = 10000
λ_bar = 0.134
# λ_bar = 0.102
# λ_bar = 0.0925
# ϑ_bar = 0.078
# ϑ_bar = 0.054
# ϑ_bar = 0.048

ϑ_bar = 0.052
# ϑ_bar = 0.036
# ϑ_bar = 0.032

# γ3 = γ3_list[1]*3.0
γ3 = γ3_list[2]

α=0.115

# ϵ=2.5
ϵ=0.1


max_iter=2000
tol=1e-7

n_y = len(y_grid)
n_k = len(k_grid)
dy = y_grid[1] - y_grid[0]
dk = k_grid[1] - k_grid[0]

(y_mat, k_mat) = np.meshgrid(y_grid, k_grid, indexing = 'ij')
stateSpace = np.hstack([y_mat.reshape(-1,1, order='F'), k_mat.reshape(-1,1,order='F')])
πa_o = np.ones((len(θ_list), n_y, n_k))/len(θ_list)
θ_mat = np.zeros((len(θ_list), n_y, n_k))
for i in range(len(θ_list)):
    θ_mat[i] = θ_list[i]
πa = πa_o

# dΛ = γ1 + γ2*y_mat + γ3*(y_mat - y_bar)*(y_mat >y_bar)
dΛ = γ1 + γ2*y_mat + γ3*(y_mat-ȳ)*(y_mat>ȳ)
# ddΛ = γ2 + γ3*(y_mat > y_bar)
ddΛ = γ2 + γ3*(y_mat>ȳ)

    
# initial guess
v0 =  (1/δ)*k_mat  -  η/δ*y_mat**2 
# initial i
a_i = κ*(1/δ)
b_i = - (1 + α*κ)*(1/δ)
c_i = α*(1/δ) - 1
i = (-b_i - np.sqrt(b_i**2 - 4*a_i*c_i))/(2*a_i)

ems = η*np.ones(y_mat.shape)
mc = 1/(α - i - α*ϑ_bar*(1 - ems/(np.exp(k_mat)*α*λ_bar))**θ )

episode = 0
lhs_error = 0.5
vd = - 1/δ

while lhs_error > tol:
    vold = v0.copy()
    v0_dy = derivatives_2d(v0,0,1,dy)
    v0_dyy = derivatives_2d(v0,0,2,dy)
    v0_dk = derivatives_2d(v0,1,1,dk)
    v0_dk[v0_dk < 1e-15] =  1e-15
    v0_dkk = derivatives_2d(v0,1,2,dk)
    # updating controls
    i_new = (1 -mc/v0_dk)*(1/κ)
#     update emission
    if θ == 2:
        a = v0_dyy*σy**2 + vd*ddΛ*σy**2 - mc*θ*ϑ_bar/(α*λ_bar**2*np.exp(2*k_mat))
        b = mc*θ*ϑ_bar/(λ_bar*np.exp(k_mat)) + v0_dy*np.sum(θ_mat*πa, axis=0) \
            + vd*dΛ*np.sum(θ_mat*πa, axis=0)
        ems_new = -b/a
        ems_new = (ems_new)*(ems_new>0)
    elif θ == 3:
        b = v0_dyy*σy**2 + vd*ddΛ*σy**2 - 2*mc*θ*ϑ_bar/(α*λ_bar**2*np.exp(2*k_mat))
        c = mc*θ*ϑ_bar/(λ_bar*np.exp(k_mat)) + v0_dy*np.sum(θ_mat*πa, axis=0) \
            + vd*dΛ*np.sum(θ_mat*πa, axis=0)
        a = mc*θ*ϑ_bar/(α**2*λ_bar**3*np.exp(3*k_mat))    
        ems_new =  (-b-np.sqrt(b**2 - 4*a*c))/(2*a)
#         ems_new = (ems_new)*(ems_new>0)

    i_new = i_new*0.05 + i*0.95
    ems_new = ems_new*0.05 + ems*0.95
    ratio = (1 - ems_new/(α*λ_bar*np.exp(k_mat)))*( (1 - ems_new/(α*λ_bar*np.exp(k_mat))) > 0 )
    consumption = α - i_new - α*ϑ_bar*ratio**θ
#     consumption[c# mc[mc < 1e-15] = 1e-1510onsumption <= 1e-15] = 1e-15
    mc_new = 1/consumption
    
#     mc_new[mc_new <= 1e-15] = 1e-15
#     mc_new = mc_new*0.05 + mc*0.95
    temp = v0_dy + vd*dΛ
    weight = np.array([-1/ξa*temp*ems_new*θ for θ in θ_list])
    weight = weight - np.max(weight, axis=0)
    πa = πa_o*np.exp(weight)
    πa[πa<1e-15] = 1e-15
    πa = πa/np.sum(πa, axis=0)
    print("min ems:", np.min(ems_new))
    print("min mc", np.min(mc_new))
    # HJB coefficient
    entropy = np.sum(πa*(np.log(πa) - np.log(πa_o)), axis=0)
    A =  -δ*np.ones(y_mat.shape)
    B_y = np.sum(θ_mat*πa, axis=0)*ems_new
    B_k = μk + i_new - 0.5*κ*i_new**2 - 0.5*σk**2
    C_yy = 0.5*ems_new**2*σy**2
    C_kk = 0.5*σk**2*np.ones(y_mat.shape)
    D = - np.log(mc_new) + k_mat + vd*(dΛ*np.sum(θ_mat*πa, axis=0)*ems_new + 0.5*ddΛ*σy**2*ems_new**2) \
        + ξa*entropy
    # PDE solver
    out = PDESolver_2d(stateSpace, A, B_y, B_k, C_yy, C_kk, D, v0, ϵ, solverType = 'False Transient')
    out_comp = out[2].reshape(v0.shape,order = "F")
    rhs = A*v0 + B_y*v0_dy + B_k*v0_dk + C_yy*v0_dyy + C_kk*v0_dkk  + D
    rhs_error = np.max(abs(rhs))
    lhs_error = np.max(abs((out_comp - v0)/ϵ))
    #     if episode % 1 == 0:
    print("Episode {:d}: PDE Error: {:.12f}; False Transient Error: {:.12f}; Iterations: {:d}; CG Error: {:.12f}".format(episode, rhs_error, lhs_error, out[0], out[1]))
    episode += 1
    v0 = out_comp
    ems = ems_new
    mc = mc_new
    i = i_new
# Out:
# min ems: -17.124352353849268
# min mc 39.99791726530605
# Episode 0: PDE Error: 1.948494489228; False Transient Error: 1.947117752121; Iterations: 5; CG Error: 0.000000000086
# min ems: -26.126484008236076
# min mc 39.99791014326011
# Episode 1: PDE Error: 1.939982854795; False Transient Error: 1.938746337090; Iterations: 8; CG Error: 0.000000000031
# min ems: -34.52663045501587
# min mc 39.997901877955464
# Episode 2: PDE Error: 1.934524771844; False Transient Error: 1.933454193330; Iterations: 10; CG Error: 0.000000000059
# min ems: -42.335193188707024
# min mc 39.99789154730988
# Episode 3: PDE Error: 2.036876009295; False Transient Error: 2.029541187404; Iterations: 13; CG Error: 0.000000000036
# min ems: -49.57483394363906
# min mc 39.99787842343965
# Episode 4: PDE Error: 2.551173639821; False Transient Error: 2.540086915337; Iterations: 15; CG Error: 0.000000000082
# min ems: -56.27671968043794
# min mc 39.997861938682654
# Episode 5: PDE Error: 3.002458830277; False Transient Error: 2.987434758759; Iterations: 18; CG Error: 0.000000000082
# min ems: -62.476900824124975
# min mc 39.99784268165719
# Episode 6: PDE Error: 3.396792490131; False Transient Error: 3.377755367353; Iterations: 21; CG Error: 0.000000000082
# min ems: -68.2130342560316
# min mc 39.86844288767803
# Episode 7: PDE Error: 3.739914591754; False Transient Error: 3.716871879552; Iterations: 24; CG Error: 0.000000000071
# min ems: -73.52190233172288
# min mc 39.65684531210162
# Episode 8: PDE Error: 4.037085811238; False Transient Error: 4.010117043562; Iterations: 27; CG Error: 0.000000000074
# min ems: -78.43796100260218
# min mc 39.51257503896167
# Episode 9: PDE Error: 4.293062162767; False Transient Error: 4.262290489766; Iterations: 30; CG Error: 0.000000000085
# min ems: -82.99259300040787
# min mc 39.4201167757511
# Episode 10: PDE Error: 4.512097155798; False Transient Error: 4.477688456109; Iterations: 33; CG Error: 0.000000000083
# min ems: -87.21404888345802
# min mc 39.366915394493674
# Episode 11: PDE Error: 4.698008571615; False Transient Error: 4.660150057042; Iterations: 36; CG Error: 0.000000000093
# min ems: -91.1276362107045
# min mc 39.34295488213585
# Episode 12: PDE Error: 4.854218184330; False Transient Error: 4.813114773993; Iterations: 40; CG Error: 0.000000000065
# min ems: -94.7560792944839
# min mc 39.3405143952471
# Episode 13: PDE Error: 4.983809076792; False Transient Error: 4.939681419827; Iterations: 43; CG Error: 0.000000000071
# min ems: -98.11988557293098
# min mc 39.35367802577321
# Episode 14: PDE Error: 5.089567657107; False Transient Error: 5.042639355684; Iterations: 46; CG Error: 0.000000000066
# min ems: -101.23765545065793
# min mc 39.37762948434719
# Episode 15: PDE Error: 5.174013602774; False Transient Error: 5.124520011615; Iterations: 49; CG Error: 0.000000000070
# min ems: -104.12636355482977
# min mc 39.4089456785872
# Episode 16: PDE Error: 5.239435531035; False Transient Error: 5.187598201501; Iterations: 51; CG Error: 0.000000000098
# min ems: -106.80154342043608
# min mc 39.44475415588529
# Episode 17: PDE Error: 5.287899777691; False Transient Error: 5.233942267436; Iterations: 54; CG Error: 0.000000000084
# min ems: -109.27747584754363
# min mc 39.483048781529234
# Episode 18: PDE Error: 5.321282864229; False Transient Error: 5.265425633348; Iterations: 56; CG Error: 0.000000000095
# min ems: -111.56733416989151
# min mc 39.52224114637348
# Episode 19: PDE Error: 5.341287210875; False Transient Error: 5.283736074080; Iterations: 59; CG Error: 0.000000000073
# min ems: -113.68328463063307
# min mc 39.56116591840572
# Episode 20: PDE Error: 5.349447687126; False Transient Error: 5.290400810671; Iterations: 62; CG Error: 0.000000000087
# min ems: -115.63659472377027
# min mc 39.5989742859532
# Episode 21: PDE Error: 5.347154664318; False Transient Error: 5.286803740313; Iterations: 67; CG Error: 0.000000000072
# min ems: -117.43771906303368
# min mc 39.63502405800218
# Episode 22: PDE Error: 5.335664225782; False Transient Error: 5.274186925209; Iterations: 68; CG Error: 0.000000000083
# min ems: -119.0963740917066
# min mc 39.66909559792931
# Episode 23: PDE Error: 5.316110482361; False Transient Error: 5.253672162218; Iterations: 70; CG Error: 0.000000000085
# min ems: -120.6215879704165
# min mc 39.700908279459476
# Episode 24: PDE Error: 5.289507014207; False Transient Error: 5.226267625565; Iterations: 72; CG Error: 0.000000000069
# min ems: -122.02177820623366
# min mc 39.730389608729915
# Episode 25: PDE Error: 5.256773939328; False Transient Error: 5.192877568479; Iterations: 73; CG Error: 0.000000000087
# min ems: -123.30478956553415
# min mc 39.7574976396628
# Episode 26: PDE Error: 5.218732661622; False Transient Error: 5.154315199978; Iterations: 75; CG Error: 0.000000000078
# min ems: -124.47794299708487
# min mc 39.78201521115068
# Episode 27: PDE Error: 5.176120000079; False Transient Error: 5.111304760408; Iterations: 76; CG Error: 0.000000000092
# min ems: -125.54807586163096
# min mc 39.80379154935262
# Episode 28: PDE Error: 5.129595135213; False Transient Error: 5.064495686715; Iterations: 78; CG Error: 0.000000000075
# min ems: -126.52157646661058
# min mc 39.82345905091462
# Episode 29: PDE Error: 5.079744920543; False Transient Error: 5.014465717818; Iterations: 80; CG Error: 0.000000000083
# min ems: -127.40442063780353
# min mc 39.84120606357373
# Episode 30: PDE Error: 5.027093741066; False Transient Error: 4.961730580969; Iterations: 81; CG Error: 0.000000000096
# min ems: -128.20220316868304
# min mc 39.85716916649778
# Episode 31: PDE Error: 4.972108963347; False Transient Error: 4.906748502107; Iterations: 83; CG Error: 0.000000000061
# min ems: -128.9201626943077
# min mc 39.87153334839999
# Episode 32: PDE Error: 4.915204089554; False Transient Error: 4.849924747726; Iterations: 83; CG Error: 0.000000000099
# min ems: -129.5632079541314
# min mc 39.884378766409064
# Episode 33: PDE Error: 4.856745704553; False Transient Error: 4.791619377792; Iterations: 84; CG Error: 0.000000000090
# min ems: -130.13594261862193
# min mc 39.89586744357872
# Episode 34: PDE Error: 4.797058808965; False Transient Error: 4.732147348280; Iterations: 84; CG Error: 0.000000000090
# min ems: -130.64268146944264
# min mc 39.90611682768929
# Episode 35: PDE Error: 4.736427136066; False Transient Error: 4.671790177895; Iterations: 85; CG Error: 0.000000000094
# min ems: -131.08747632863125
# min mc 39.91526650824639
# Episode 36: PDE Error: 4.675103223947; False Transient Error: 4.610791396653; Iterations: 86; CG Error: 0.000000000079
# min ems: -131.47412931655592
# min mc 39.92340648539904
# Episode 37: PDE Error: 4.613306393851; False Transient Error: 4.549365502684; Iterations: 86; CG Error: 0.000000000093
# min ems: -131.80621188189753
# min mc 39.9306096052481
# Episode 38: PDE Error: 4.551229492765; False Transient Error: 4.487700120675; Iterations: 87; CG Error: 0.000000000090
# min ems: -132.08707974059698
# min mc 39.93699432874256
# Episode 39: PDE Error: 4.489040552042; False Transient Error: 4.425957866036; Iterations: 87; CG Error: 0.000000000088
# min ems: -132.31988563662773
# min mc 39.942648631574116
# Episode 40: PDE Error: 4.426884128831; False Transient Error: 4.364279923940; Iterations: 87; CG Error: 0.000000000099
# min ems: -132.50759642568934
# min mc 39.947612017840584
# Episode 41: PDE Error: 4.364886450810; False Transient Error: 4.302787813808; Iterations: 88; CG Error: 0.000000000077
# min ems: -132.65300184033222
# min mc 39.95191536973194
# Episode 42: PDE Error: 4.303155222807; False Transient Error: 4.241585909073; Iterations: 89; CG Error: 0.000000000072
# min ems: -132.75872584892826
# min mc 39.95530462537699
# Episode 43: PDE Error: 4.241782892470; False Transient Error: 4.180764116717; Iterations: 88; CG Error: 0.000000000090
# min ems: -132.82723851103376
# min mc 39.95810654333904
# Episode 44: PDE Error: 4.180849263483; False Transient Error: 4.120397682392; Iterations: 88; CG Error: 0.000000000082
# min ems: -132.86086148966652
# min mc 39.96013412984302
# Episode 45: PDE Error: 4.120419667808; False Transient Error: 4.060550362688; Iterations: 88; CG Error: 0.000000000097
# min ems: -132.8617805756404
# min mc 39.961711679492865
# Episode 46: PDE Error: 4.060550654537; False Transient Error: 4.001275217239; Iterations: 88; CG Error: 0.000000000097
# min ems: -132.8320511130019
# min mc 39.96293490898919
# Episode 47: PDE Error: 4.001287270841; False Transient Error: 3.942615560859; Iterations: 89; CG Error: 0.000000000072
# min ems: -132.7736075796269
# min mc 39.96388880326763
# Episode 48: PDE Error: 3.942666892012; False Transient Error: 3.884607971859; Iterations: 88; CG Error: 0.000000000098
# min ems: -132.688273751547
# min mc 39.96463037652201
# Episode 49: PDE Error: 3.884721383223; False Transient Error: 3.827280344921; Iterations: 89; CG Error: 0.000000000077
# min ems: -132.57776447583404
# min mc 39.96517903972083
# Episode 50: PDE Error: 3.827473198877; False Transient Error: 3.770655580282; Iterations: 88; CG Error: 0.000000000091
# min ems: -132.44369695280588
# min mc 39.96558881155509
# Episode 51: PDE Error: 3.770941833234; False Transient Error: 3.714750289269; Iterations: 88; CG Error: 0.000000000083
# min ems: -132.28759344228752
# min mc 39.96586736263722
# Episode 52: PDE Error: 3.715140201193; False Transient Error: 3.659576532380; Iterations: 88; CG Error: 0.000000000080
# min ems: -132.11088781808937
# min mc 39.9660657138854
# Episode 53: PDE Error: 3.660077453674; False Transient Error: 3.605142405472; Iterations: 88; CG Error: 0.000000000079
# min ems: -131.91493062370077
# min mc 39.96613760457962
# Episode 54: PDE Error: 3.605759188714; False Transient Error: 3.551452502643; Iterations: 88; CG Error: 0.000000000071
# min ems: -131.70099412182418
# min mc 39.9661448518886
# Episode 55: PDE Error: 3.552187913455; False Transient Error: 3.498508545575; Iterations: 87; CG Error: 0.000000000095
# min ems: -131.47027745092592
# min mc 39.96609616391387
# Episode 56: PDE Error: 3.499363770687; False Transient Error: 3.446309349277; Iterations: 87; CG Error: 0.000000000089
# min ems: -131.22390942204711
# min mc 39.96599668891474
# Episode 57: PDE Error: 3.447283623921; False Transient Error: 3.394851548260; Iterations: 87; CG Error: 0.000000000085
# min ems: -130.96295403587922
# min mc 39.96584902399539
# Episode 58: PDE Error: 3.395943145571; False Transient Error: 3.344129844462; Iterations: 86; CG Error: 0.000000000094
# min ems: -130.68841375777345
# min mc 39.965659725623894
# Episode 59: PDE Error: 3.345335885935; False Transient Error: 3.294137449878; Iterations: 85; CG Error: 0.000000000099
# min ems: -130.40123485303295
# min mc 39.96543841654564
# Episode 60: PDE Error: 3.295454551196; False Transient Error: 3.244867213008; Iterations: 85; CG Error: 0.000000000097
# min ems: -130.10231025572978
# min mc 39.965191499783096
# Episode 61: PDE Error: 3.246290781457; False Transient Error: 3.196309601799; Iterations: 85; CG Error: 0.000000000100
# min ems: -129.79248213192082
# min mc 39.96492162565841
# Episode 62: PDE Error: 3.197835281426; False Transient Error: 3.148454692002; Iterations: 85; CG Error: 0.000000000073
# min ems: -129.47254365455103
# min mc 39.96463116600225
# Episode 63: PDE Error: 3.150077297160; False Transient Error: 3.101291849130; Iterations: 85; CG Error: 0.000000000070
# min ems: -129.14324237392162
# min mc 39.9643222428889
# Episode 64: PDE Error: 3.103005795714; False Transient Error: 3.054809267866; Iterations: 84; CG Error: 0.000000000092
# min ems: -128.80528257078865
# min mc 39.963996754570026
# Episode 65: PDE Error: 3.056609238597; False Transient Error: 3.008996088130; Iterations: 84; CG Error: 0.000000000068
# min ems: -128.45932807539194
# min mc 39.963650912947024
# Episode 66: PDE Error: 3.010875896619; False Transient Error: 2.963839616981; Iterations: 83; CG Error: 0.000000000093
# min ems: -128.10600453452105
# min mc 39.963290264493665
# Episode 67: PDE Error: 2.965793994835; False Transient Error: 2.919328862716; Iterations: 83; CG Error: 0.000000000078
# min ems: -127.74590227892509
# min mc 39.96291761695879
# Episode 68: PDE Error: 2.921351982315; False Transient Error: 2.875450021045; Iterations: 81; CG Error: 0.000000000083
# min ems: -127.37957624272585
# min mc 39.962534183562695
# Episode 69: PDE Error: 2.877537163380; False Transient Error: 2.832191732956; Iterations: 80; CG Error: 0.000000000093
# min ems: -127.00754843112504
# min mc 39.96214104931641
# Episode 70: PDE Error: 2.834336814420; False Transient Error: 2.789542840596; Iterations: 75; CG Error: 0.000000000091
# min ems: -126.63031007640794
# min mc 39.961739184601605
# Episode 71: PDE Error: 2.791738326948; False Transient Error: 2.747492446916; Iterations: 78; CG Error: 0.000000000095
# min ems: -126.24833244940532
# min mc 39.9612997798358
# Episode 72: PDE Error: 2.749735325630; False Transient Error: 2.706024005738; Iterations: 78; CG Error: 0.000000000098
# min ems: -125.86204727697384
# min mc 39.96084170242123
# Episode 73: PDE Error: 2.708309237522; False Transient Error: 2.665128268726; Iterations: 78; CG Error: 0.000000000085
# min ems: -125.47186537838138
# min mc 39.96037646155463
# Episode 74: PDE Error: 2.667450332316; False Transient Error: 2.624792583991; Iterations: 77; CG Error: 0.000000000097
# min ems: -125.07817253981574
# min mc 39.95990475157481
# Episode 75: PDE Error: 2.627146710815; False Transient Error: 2.585007008543; Iterations: 77; CG Error: 0.000000000079
# min ems: -124.6813354164736
# min mc 39.9594271939007
# Episode 76: PDE Error: 2.587389314015; False Transient Error: 2.545758921824; Iterations: 76; CG Error: 0.000000000095
# min ems: -124.28169511633652
# min mc 39.958944344776135
# Episode 77: PDE Error: 2.548165135451; False Transient Error: 2.507038653355; Iterations: 76; CG Error: 0.000000000078
# min ems: -123.87957445383398
# min mc 39.958449653591
# Episode 78: PDE Error: 2.509464324136; False Transient Error: 2.468833801120; Iterations: 75; CG Error: 0.000000000094
# min ems: -123.47527411892516
# min mc 39.957907014912415
# Episode 79: PDE Error: 2.471274790724; False Transient Error: 2.431135170332; Iterations: 75; CG Error: 0.000000000075
# min ems: -123.06907905036573
# min mc 39.95736000434715
# Episode 80: PDE Error: 2.433587359174; False Transient Error: 2.393932110168; Iterations: 74; CG Error: 0.000000000086
# min ems: -122.66125962036948
# min mc 39.956809016577466
# Episode 81: PDE Error: 2.396393888122; False Transient Error: 2.357214996608; Iterations: 73; CG Error: 0.000000000089
# min ems: -122.25206423480469
# min mc 39.95625440532414
# Episode 82: PDE Error: 2.359681390056; False Transient Error: 2.320973883154; Iterations: 73; CG Error: 0.000000000080
# min ems: -121.84173184414286
# min mc 39.95569648766396
# Episode 83: PDE Error: 2.323443551583; False Transient Error: 2.285199897664; Iterations: 72; CG Error: 0.000000000084
# min ems: -121.43048115931788
# min mc 39.95508884529797
# Episode 84: PDE Error: 2.287668008543; False Transient Error: 2.249882508536; Iterations: 72; CG Error: 0.000000000069
# min ems: -121.01852113643307
# min mc 39.95446649374032
# Episode 85: PDE Error: 2.252347863071; False Transient Error: 2.215016500041; Iterations: 70; CG Error: 0.000000000095
# min ems: -120.6060514945697
# min mc 39.9538413579799
# Episode 86: PDE Error: 2.217476586314; False Transient Error: 2.180587340769; Iterations: 71; CG Error: 0.000000000098
# min ems: -120.19325131702682
# min mc 39.95321366214238
# Episode 87: PDE Error: 2.183041671241; False Transient Error: 2.146590475644; Iterations: 70; CG Error: 0.000000000095
# min ems: -119.78028426801986
# min mc 39.952583607441234
# Episode 88: PDE Error: 2.149031570739; False Transient Error: 2.113015575738; Iterations: 70; CG Error: 0.000000000069
# min ems: -119.36731887628628
# min mc 39.951891523756146
# Episode 89: PDE Error: 2.115447071645; False Transient Error: 2.079860081868; Iterations: 68; CG Error: 0.000000000093
# min ems: -118.95450656410762
# min mc 39.95119137881458
# Episode 90: PDE Error: 2.082277288021; False Transient Error: 2.047107452911; Iterations: 69; CG Error: 0.000000000084
# min ems: -118.54198244743795
# min mc 39.95048919938489
# Episode 91: PDE Error: 2.049511502375; False Transient Error: 2.014757212098; Iterations: 68; CG Error: 0.000000000077
# min ems: -118.12987752339552
# min mc 39.94978512746021
# Episode 92: PDE Error: 2.017144149514; False Transient Error: 1.982800514147; Iterations: 67; CG Error: 0.000000000092
# min ems: -117.71831400614928
# min mc 39.94907617815554
# Episode 93: PDE Error: 1.985168210276; False Transient Error: 1.951227760416; Iterations: 67; CG Error: 0.000000000076
# min ems: -117.30740518135951
# min mc 39.94829573677314
# Episode 94: PDE Error: 1.953576680489; False Transient Error: 1.920034528729; Iterations: 67; CG Error: 0.000000000088
# min ems: -116.8972602949132
# min mc 39.94751362522562
# Episode 95: PDE Error: 1.922364836914; False Transient Error: 1.889213512208; Iterations: 67; CG Error: 0.000000000073
# min ems: -116.48797462749761
# min mc 39.9467299437062
# Episode 96: PDE Error: 1.891522753828; False Transient Error: 1.858761533747; Iterations: 65; CG Error: 0.000000000099
# min ems: -116.07964150646714
# min mc 39.94594478248706
# Episode 97: PDE Error: 1.861046116725; False Transient Error: 1.828666484639; Iterations: 65; CG Error: 0.000000000090
# min ems: -115.67234494937482
# min mc 39.945141369944714
# Episode 98: PDE Error: 1.830927850085; False Transient Error: 1.798925269544; Iterations: 65; CG Error: 0.000000000074
# min ems: -115.26616636126235
# min mc 39.94428555005914
# Episode 99: PDE Error: 1.801163734181; False Transient Error: 1.769534374896; Iterations: 64; CG Error: 0.000000000084
# min ems: -114.86118336639524
# min mc 39.94342839003323
# Episode 100: PDE Error: 1.771749149926; False Transient Error: 1.751160067620; Iterations: 64; CG Error: 0.000000000070
# min ems: -114.45746088713076
# min mc 39.942558295282
# Episode 101: PDE Error: 1.749573984081; False Transient Error: 1.749437354862; Iterations: 63; CG Error: 0.000000000085
# min ems: -114.05506235467793
# min mc 39.94168631925197
# Episode 102: PDE Error: 1.747851006325; False Transient Error: 1.747716058899; Iterations: 63; CG Error: 0.000000000072
# min ems: -113.65404613330865
# min mc 39.940813167468704
# Episode 103: PDE Error: 1.746129157489; False Transient Error: 1.745995549198; Iterations: 62; CG Error: 0.000000000085
# min ems: -113.25446715226147
# min mc 39.939866066567625
# Episode 104: PDE Error: 1.744408462900; False Transient Error: 1.744276634588; Iterations: 62; CG Error: 0.000000000072
# min ems: -112.85637402344184
# min mc 39.93891642994258
# Episode 105: PDE Error: 1.742688906709; False Transient Error: 1.742559014518; Iterations: 61; CG Error: 0.000000000085
# min ems: -112.45981385909644
# min mc 39.937965688874066
# Episode 106: PDE Error: 1.740981359381; False Transient Error: 1.740842821391; Iterations: 60; CG Error: 0.000000000097
# min ems: -112.06482770074314
# min mc 39.93701388087653
# Episode 107: PDE Error: 1.739277395178; False Transient Error: 1.739127173892; Iterations: 60; CG Error: 0.000000000082
# min ems: -111.6714537196907
# min mc 39.93606058989388
# Episode 108: PDE Error: 1.737574344270; False Transient Error: 1.737412611116; Iterations: 59; CG Error: 0.000000000096
# min ems: -111.2797283593721
# min mc 39.934907762267486
# Episode 109: PDE Error: 1.735872224985; False Transient Error: 1.735699404870; Iterations: 59; CG Error: 0.000000000080
# min ems: -110.88968209105258
# min mc 39.93365723755595
# Episode 110: PDE Error: 1.734171043558; False Transient Error: 1.733986867420; Iterations: 58; CG Error: 0.000000000097
# min ems: -110.50134270827782
# min mc 39.932396406302274
# Episode 111: PDE Error: 1.732470787098; False Transient Error: 1.732276173179; Iterations: 58; CG Error: 0.000000000081
# min ems: -110.11473746330765
# min mc 39.93112530113515
# Episode 112: PDE Error: 1.730771497938; False Transient Error: 1.730567692269; Iterations: 57; CG Error: 0.000000000090
# min ems: -109.72989071493265
# min mc 39.929843960747164
# Episode 113: PDE Error: 1.729073171742; False Transient Error: 1.728870821797; Iterations: 57; CG Error: 0.000000000075
# min ems: -109.34682274441039
# min mc 39.92855050162988
# Episode 114: PDE Error: 1.727375833307; False Transient Error: 1.727174654778; Iterations: 56; CG Error: 0.000000000089
# min ems: -108.96555063354944
# min mc 39.92720338599935
# Episode 115: PDE Error: 1.725679514492; False Transient Error: 1.725479684652; Iterations: 55; CG Error: 0.000000000098
# min ems: -108.58609222046877
# min mc 39.925846036387654
# Episode 116: PDE Error: 1.723984210666; False Transient Error: 1.723786043291; Iterations: 55; CG Error: 0.000000000081
# min ems: -108.20846237188283
# min mc 39.92447850333938
# Episode 117: PDE Error: 1.722289909480; False Transient Error: 1.722093686406; Iterations: 54; CG Error: 0.000000000089
# min ems: -107.83267219978879
# min mc 39.92310083949943
# Episode 118: PDE Error: 1.720596599107; False Transient Error: 1.720401935594; Iterations: 54; CG Error: 0.000000000075
# min ems: -107.45873441064566
# min mc 39.92168679086534
# Episode 119: PDE Error: 1.718904319850; False Transient Error: 1.718711548431; Iterations: 53; CG Error: 0.000000000094
# min ems: -107.0866571070379
# min mc 39.92013643150116
# Episode 120: PDE Error: 1.717213053588; False Transient Error: 1.717021830701; Iterations: 53; CG Error: 0.000000000080
# min ems: -106.7164494188148
# min mc 39.91858394645929
# Episode 121: PDE Error: 1.715527053270; False Transient Error: 1.715333189427; Iterations: 53; CG Error: 0.000000000069
# min ems: -106.3481181751328
# min mc 39.91702934979588
# Episode 122: PDE Error: 1.713850093436; False Transient Error: 1.713645331224; Iterations: 52; CG Error: 0.000000000089
# min ems: -105.98166698941372
# min mc 39.91547265435408
# Episode 123: PDE Error: 1.712173959690; False Transient Error: 1.711958959830; Iterations: 52; CG Error: 0.000000000077
# min ems: -105.61710064104753
# min mc 39.91391387178687
# Episode 124: PDE Error: 1.710498684031; False Transient Error: 1.710273303273; Iterations: 51; CG Error: 0.000000000097
# min ems: -105.25441917573251
# min mc 39.91235301305984
# Episode 125: PDE Error: 1.708824253833; False Transient Error: 1.708589158681; Iterations: 51; CG Error: 0.000000000085
# min ems: -104.89362610415701
# min mc 39.91079008778174
# Episode 126: PDE Error: 1.707150709995; False Transient Error: 1.706906071723; Iterations: 51; CG Error: 0.000000000074
# min ems: -104.53472233614833
# min mc 39.90922510474572
# Episode 127: PDE Error: 1.705478061788; False Transient Error: 1.705224053096; Iterations: 51; CG Error: 0.000000000065
# min ems: -104.17770741644065
# min mc 39.90765807200406
# Episode 128: PDE Error: 1.703806318537; False Transient Error: 1.703543482503; Iterations: 50; CG Error: 0.000000000092
# min ems: -103.82257855949264
# min mc 39.90608899707632
# Episode 129: PDE Error: 1.702135506244; False Transient Error: 1.701872544390; Iterations: 50; CG Error: 0.000000000081
# min ems: -103.46933402707579
# min mc 39.904517886698216
# Episode 130: PDE Error: 1.700465611249; False Transient Error: 1.700204299456; Iterations: 50; CG Error: 0.000000000072
# min ems: -103.11797083507402
# min mc 39.90294474705507
# Episode 131: PDE Error: 1.698796644308; False Transient Error: 1.698536519708; Iterations: 49; CG Error: 0.000000000092
# min ems: -102.76848270385688
# min mc 39.90129476973867
# Episode 132: PDE Error: 1.697128637724; False Transient Error: 1.696870244573; Iterations: 49; CG Error: 0.000000000080
# min ems: -102.42086690889285
# min mc 39.89958650269589
# Episode 133: PDE Error: 1.695461573550; False Transient Error: 1.695204982044; Iterations: 48; CG Error: 0.000000000098
# min ems: -102.07511906166276
# min mc 39.897876192681366
# Episode 134: PDE Error: 1.693795452504; False Transient Error: 1.693540499276; Iterations: 48; CG Error: 0.000000000084
# min ems: -101.73123281961074
# min mc 39.89616384607435
# Episode 135: PDE Error: 1.692141177959; False Transient Error: 1.691877598846; Iterations: 47; CG Error: 0.000000000098
# min ems: -101.3892014282468
# min mc 39.89444946899066
# Episode 136: PDE Error: 1.690488067151; False Transient Error: 1.690214905809; Iterations: 47; CG Error: 0.000000000084
# min ems: -101.049018508112
# min mc 39.89273306710372
# Episode 137: PDE Error: 1.688835741824; False Transient Error: 1.688553233632; Iterations: 47; CG Error: 0.000000000071
# min ems: -100.71067680784074
# min mc 39.8910146458177
# Episode 138: PDE Error: 1.687184216277; False Transient Error: 1.686892431028; Iterations: 46; CG Error: 0.000000000086
# min ems: -100.37417080192091
# min mc 39.88929421060865
# Episode 139: PDE Error: 1.685543708986; False Transient Error: 1.685232423537; Iterations: 45; CG Error: 0.000000000090
# min ems: -100.03949452113264
# min mc 39.88757176638896
# Episode 140: PDE Error: 1.683948023679; False Transient Error: 1.683574414574; Iterations: 44; CG Error: 0.000000000099
# min ems: -99.70664053842516
# min mc 39.885847317453134
# Episode 141: PDE Error: 1.682352232230; False Transient Error: 1.681916861813; Iterations: 44; CG Error: 0.000000000080
# min ems: -99.37559452525068
# min mc 39.884120868450886
# Episode 142: PDE Error: 1.680756426979; False Transient Error: 1.680260789440; Iterations: 43; CG Error: 0.000000000090
# min ems: -99.04635048702406
# min mc 39.88239242368636
# Episode 143: PDE Error: 1.679160556633; False Transient Error: 1.678614086281; Iterations: 43; CG Error: 0.000000000076
# min ems: -98.7188937187067
# min mc 39.88066198756683
# Episode 144: PDE Error: 1.677564747677; False Transient Error: 1.676969444585; Iterations: 43; CG Error: 0.000000000065
# min ems: -98.39321305580535
# min mc 39.878929564368455
# Episode 145: PDE Error: 1.675969020968; False Transient Error: 1.675325936756; Iterations: 42; CG Error: 0.000000000092
# min ems: -98.06930029934546
# min mc 39.87719515852355
# Episode 146: PDE Error: 1.674373419500; False Transient Error: 1.673682875274; Iterations: 42; CG Error: 0.000000000082
# min ems: -97.74714383022643
# min mc 39.87545877403199
# Episode 147: PDE Error: 1.672777935215; False Transient Error: 1.672040735524; Iterations: 42; CG Error: 0.000000000073
# min ems: -97.4267332245157
# min mc 39.87372041484008
# Episode 148: PDE Error: 1.671182592337; False Transient Error: 1.670400141907; Iterations: 41; CG Error: 0.000000000098
# min ems: -97.1080629149471
# min mc 39.871980085185015
# Episode 149: PDE Error: 1.669587490482; False Transient Error: 1.668759711415; Iterations: 41; CG Error: 0.000000000089
# min ems: -96.79111912256697
# min mc 39.87012864497655
# Episode 150: PDE Error: 1.667992560306; False Transient Error: 1.667120245179; Iterations: 41; CG Error: 0.000000000081
# min ems: -96.4758907585848
# min mc 39.86825547643143
# Episode 151: PDE Error: 1.666397826980; False Transient Error: 1.665481743648; Iterations: 41; CG Error: 0.000000000074
# min ems: -96.16236735217538
# min mc 39.86638043390833
# Episode 152: PDE Error: 1.664803314527; False Transient Error: 1.663843997717; Iterations: 40; CG Error: 0.000000000099
# min ems: -95.85053938118156
# min mc 39.86450352357426
# Episode 153: PDE Error: 1.663209055134; False Transient Error: 1.662207563297; Iterations: 40; CG Error: 0.000000000089
# min ems: -95.5403962782409
# min mc 39.86262475183482
# Episode 154: PDE Error: 1.661615064102; False Transient Error: 1.660572066517; Iterations: 40; CG Error: 0.000000000080
# min ems: -95.23192747399845
# min mc 39.86074412511825
# Episode 155: PDE Error: 1.660021361493; False Transient Error: 1.658945277710; Iterations: 40; CG Error: 0.000000000071
# min ems: -94.92512238595214
# min mc 39.85886164988189
# Episode 156: PDE Error: 1.658427967028; False Transient Error: 1.657321968969; Iterations: 39; CG Error: 0.000000000098
# min ems: -94.6199755604916
# min mc 39.856977332191505
# Episode 157: PDE Error: 1.656834834559; False Transient Error: 1.655697853419; Iterations: 39; CG Error: 0.000000000088
# min ems: -94.31647255072187
# min mc 39.8550911787009
# Episode 158: PDE Error: 1.655242065879; False Transient Error: 1.654074652871; Iterations: 39; CG Error: 0.000000000078
# min ems: -94.0146016828857
# min mc 39.85320319609072
# Episode 159: PDE Error: 1.653649676117; False Transient Error: 1.652452363664; Iterations: 39; CG Error: 0.000000000070
# min ems: -93.71435193623284
# min mc 39.85131339107607
# Episode 160: PDE Error: 1.652057680610; False Transient Error: 1.650830984208; Iterations: 39; CG Error: 0.000000000062
# min ems: -93.41571244558676
# min mc 39.84942177041567
# Episode 161: PDE Error: 1.650466094790; False Transient Error: 1.649210415451; Iterations: 38; CG Error: 0.000000000090
# min ems: -93.1186732513089
# min mc 39.8475283408241
# Episode 162: PDE Error: 1.648874906279; False Transient Error: 1.647590954020; Iterations: 38; CG Error: 0.000000000080
# min ems: -92.82322346844374
# min mc 39.84563310918322
# Episode 163: PDE Error: 1.647284161189; False Transient Error: 1.645972375813; Iterations: 38; CG Error: 0.000000000072
# min ems: -92.52935222379837
# min mc 39.84373608243664
# Episode 164: PDE Error: 1.645693874926; False Transient Error: 1.644353191696; Iterations: 37; CG Error: 0.000000000099
# min ems: -92.23705539633107
# min mc 39.841837267916716
# Episode 165: PDE Error: 1.644104104519; False Transient Error: 1.642738984898; Iterations: 37; CG Error: 0.000000000090
# min ems: -91.9463171182286
# min mc 39.839936672612644
# Episode 166: PDE Error: 1.642514809314; False Transient Error: 1.641131502994; Iterations: 37; CG Error: 0.000000000081
# min ems: -91.65712532682049
# min mc 39.83803430360892
# Episode 167: PDE Error: 1.640926006918; False Transient Error: 1.639524850268; Iterations: 37; CG Error: 0.000000000073
# min ems: -91.36946904499342
# min mc 39.83613016808653
# Episode 168: PDE Error: 1.639337714018; False Transient Error: 1.637919401892; Iterations: 36; CG Error: 0.000000000099
# min ems: -91.08334137361388
# min mc 39.83422427370143
# Episode 169: PDE Error: 1.637749998715; False Transient Error: 1.636314283876; Iterations: 36; CG Error: 0.000000000089
# min ems: -90.79872966508587
# min mc 39.83231662774014
# Episode 170: PDE Error: 1.636162814930; False Transient Error: 1.634710018640; Iterations: 36; CG Error: 0.000000000080
# min ems: -90.51562294373328
# min mc 39.83040723760215
# Episode 171: PDE Error: 1.634576178389; False Transient Error: 1.633106608812; Iterations: 36; CG Error: 0.000000000072
# min ems: -90.2340108336243
# min mc 39.82849611079875
# Episode 172: PDE Error: 1.632990104209; False Transient Error: 1.631504058081; Iterations: 36; CG Error: 0.000000000065
# min ems: -89.95388323802689
# min mc 39.82658325495178
# Episode 173: PDE Error: 1.631404606963; False Transient Error: 1.629902092391; Iterations: 35; CG Error: 0.000000000095
# min ems: -89.67523563649303
# min mc 39.82466867775131
# Episode 174: PDE Error: 1.629819682597; False Transient Error: 1.628301470655; Iterations: 35; CG Error: 0.000000000086
# min ems: -89.39805418721204
# min mc 39.82275238706269
# Episode 175: PDE Error: 1.628235372789; False Transient Error: 1.626707974702; Iterations: 35; CG Error: 0.000000000078
# min ems: -89.12232805333012
# min mc 39.8207623496692
# Episode 176: PDE Error: 1.626651687856; False Transient Error: 1.625116670243; Iterations: 35; CG Error: 0.000000000071
# min ems: -88.84804730834502
# min mc 39.818726083904664
# Episode 177: PDE Error: 1.625068638378; False Transient Error: 1.623526148486; Iterations: 35; CG Error: 0.000000000065
# min ems: -88.57520233678942
# min mc 39.816688395285546
# Episode 178: PDE Error: 1.623486235079; False Transient Error: 1.621936957356; Iterations: 34; CG Error: 0.000000000093
# min ems: -88.30378775067153
# min mc 39.81464929506181
# Episode 179: PDE Error: 1.621904426845; False Transient Error: 1.620347922740; Iterations: 34; CG Error: 0.000000000084
# min ems: -88.03378964526188
# min mc 39.81260879514835
# Episode 180: PDE Error: 1.620323300919; False Transient Error: 1.618759677709; Iterations: 34; CG Error: 0.000000000072
# min ems: -87.76519051538423
# min mc 39.8105669075686
# Episode 181: PDE Error: 1.618742867703; False Transient Error: 1.617172304361; Iterations: 34; CG Error: 0.000000000065
# min ems: -87.4980116395608
# min mc 39.80852364442015
# Episode 182: PDE Error: 1.617163132255; False Transient Error: 1.615585779684; Iterations: 34; CG Error: 0.000000000064
# min ems: -87.23222366629987
# min mc 39.806479017892144
# Episode 183: PDE Error: 1.615584101997; False Transient Error: 1.614006720597; Iterations: 33; CG Error: 0.000000000097
# min ems: -86.9678221838858
# min mc 39.80443304006587
# Episode 184: PDE Error: 1.614005774372; False Transient Error: 1.612429056582; Iterations: 33; CG Error: 0.000000000089
# min ems: -86.70479344353774
# min mc 39.80238572339858
# Episode 185: PDE Error: 1.612428169539; False Transient Error: 1.610852126682; Iterations: 33; CG Error: 0.000000000081
# min ems: -86.44312787093232
# min mc 39.8003370804492
# Episode 186: PDE Error: 1.610851298054; False Transient Error: 1.609275942377; Iterations: 33; CG Error: 0.000000000074
# min ems: -86.1828169164303
# min mc 39.798287123879845
# Episode 187: PDE Error: 1.609275169973; False Transient Error: 1.607700513745; Iterations: 33; CG Error: 0.000000000068
# min ems: -85.92385229874941
# min mc 39.79623586645782
# Episode 188: PDE Error: 1.607699794964; False Transient Error: 1.606125850234; Iterations: 33; CG Error: 0.000000000062
# min ems: -85.66622583090663
# min mc 39.7941833210575
# Episode 189: PDE Error: 1.606125182382; False Transient Error: 1.604551286349; Iterations: 32; CG Error: 0.000000000093
# min ems: -85.40993773918917
# min mc 39.79212950089653
# Episode 190: PDE Error: 1.604551397527; False Transient Error: 1.602978323425; Iterations: 32; CG Error: 0.000000000086
# min ems: -85.15497354069129
# min mc 39.79007441899484
# Episode 191: PDE Error: 1.602978375748; False Transient Error: 1.601406129490; Iterations: 32; CG Error: 0.000000000079
# min ems: -84.90132335854922
# min mc 39.78801808849567
# Episode 192: PDE Error: 1.601406129343; False Transient Error: 1.599834716568; Iterations: 32; CG Error: 0.000000000072
# min ems: -84.64897873942621
# min mc 39.785960522665995
# Episode 193: PDE Error: 1.599834669717; False Transient Error: 1.598264095916; Iterations: 32; CG Error: 0.000000000067
# min ems: -84.39793173786475
# min mc 39.78390173489406
# Episode 194: PDE Error: 1.598264007528; False Transient Error: 1.596693174916; Iterations: 31; CG Error: 0.000000000096
# min ems: -84.14818077207659
# min mc 39.781841739131025
# Episode 195: PDE Error: 1.596694212875; False Transient Error: 1.595124288555; Iterations: 31; CG Error: 0.000000000088
# min ems: -83.89971404770549
# min mc 39.77978054889853
# Episode 196: PDE Error: 1.595125226168; False Transient Error: 1.593556215042; Iterations: 31; CG Error: 0.000000000080
# min ems: -83.65252261672019
# min mc 39.777718177851845
# Episode 197: PDE Error: 1.593557057172; False Transient Error: 1.591988979220; Iterations: 31; CG Error: 0.000000000074
# min ems: -83.4066004438557
# min mc 39.77565463977174
# Episode 198: PDE Error: 1.591989714504; False Transient Error: 1.590422542287; Iterations: 31; CG Error: 0.000000000067
# min ems: -83.16193744989856
# min mc 39.773589948580785
# Episode 199: PDE Error: 1.590423208965; False Transient Error: 1.588856962153; Iterations: 31; CG Error: 0.000000000062
# min ems: -82.9185267926671
# min mc 39.77152411831801
# Episode 200: PDE Error: 1.588857548404; False Transient Error: 1.587292009531; Iterations: 30; CG Error: 0.000000000098
# min ems: -82.67636825398115
# min mc 39.769457163294135
# Episode 201: PDE Error: 1.587292726857; False Transient Error: 1.585728076002; Iterations: 30; CG Error: 0.000000000090
# min ems: -82.43545032904323
# min mc 39.767389097771144
# Episode 202: PDE Error: 1.585728779763; False Transient Error: 1.584165031904; Iterations: 30; CG Error: 0.000000000082
# min ems: -82.19576458121554
# min mc 39.76531993612726
# Episode 203: PDE Error: 1.584165710600; False Transient Error: 1.582602878651; Iterations: 30; CG Error: 0.000000000075
# min ems: -81.95730340955865
# min mc 39.76324969285531
# Episode 204: PDE Error: 1.582603523952; False Transient Error: 1.581041616016; Iterations: 30; CG Error: 0.000000000070
# min ems: -81.72005968751434
# min mc 39.76117838256234
# Episode 205: PDE Error: 1.581042225580; False Transient Error: 1.579481247685; Iterations: 30; CG Error: 0.000000000065
# min ems: -81.48402667401041
# min mc 39.759106019967994
# Episode 206: PDE Error: 1.579481821723; False Transient Error: 1.577921779846; Iterations: 30; CG Error: 0.000000000060
# min ems: -81.24919785651636
# min mc 39.7570326199031
# Episode 207: PDE Error: 1.577922318695; False Transient Error: 1.576364139792; Iterations: 29; CG Error: 0.000000000093
# min ems: -81.01557299533933
# min mc 39.75495819700487
# Episode 208: PDE Error: 1.576363646315; False Transient Error: 1.574806343161; Iterations: 29; CG Error: 0.000000000086
# min ems: -80.78314098594362
# min mc 39.75288276640098
# Episode 209: PDE Error: 1.574805906586; False Transient Error: 1.573249501173; Iterations: 29; CG Error: 0.000000000081
# min ems: -80.55189403402288
# min mc 39.750806343307566
# Episode 210: PDE Error: 1.573249101226; False Transient Error: 1.571693615489; Iterations: 29; CG Error: 0.000000000076
# min ems: -80.32182548532758
# min mc 39.748728943028766
# Episode 211: PDE Error: 1.571693232753; False Transient Error: 1.570138685390; Iterations: 29; CG Error: 0.000000000073
# min ems: -80.09292912859709
# min mc 39.746650580960164
# Episode 212: PDE Error: 1.570138304529; False Transient Error: 1.568584709388; Iterations: 29; CG Error: 0.000000000070
# min ems: -79.86519894831264
# min mc 39.74457127259169
# Episode 213: PDE Error: 1.568584320717; False Transient Error: 1.567031686989; Iterations: 29; CG Error: 0.000000000066
# min ems: -79.63862902879907
# min mc 39.74249103350974
# Episode 214: PDE Error: 1.567031286119; False Transient Error: 1.565480330125; Iterations: 28; CG Error: 0.000000000097
# min ems: -79.41322411905786
# min mc 39.740409879057694
# Episode 215: PDE Error: 1.565479192114; False Transient Error: 1.563929129748; Iterations: 28; CG Error: 0.000000000092
# min ems: -79.18897097588088
# min mc 39.738327825106445
# Episode 216: PDE Error: 1.563928061580; False Transient Error: 1.562378902638; Iterations: 28; CG Error: 0.000000000088
# min ems: -78.96586126204397
# min mc 39.73624488760814
# Episode 217: PDE Error: 1.562377899727; False Transient Error: 1.560829654036; Iterations: 28; CG Error: 0.000000000083
# min ems: -78.74388826770705
# min mc 39.73416108259635
# Episode 218: PDE Error: 1.560828711632; False Transient Error: 1.559281389272; Iterations: 28; CG Error: 0.000000000079
# min ems: -78.52304576385913
# min mc 39.73207642618843
# Episode 219: PDE Error: 1.559280502213; False Transient Error: 1.557734115556; Iterations: 28; CG Error: 0.000000000075
# min ems: -78.30332716534596
# min mc 39.729990934587406
# Episode 220: PDE Error: 1.557733275610; False Transient Error: 1.556187866695; Iterations: 28; CG Error: 0.000000000060
# min ems: -78.08472514724463
# min mc 39.72790462408984
# Episode 221: PDE Error: 1.556187027048; False Transient Error: 1.554642538872; Iterations: 28; CG Error: 0.000000000068
# min ems: -77.86724210562332
# min mc 39.72581751105897
# Episode 222: PDE Error: 1.554641785573; False Transient Error: 1.553098252101; Iterations: 28; CG Error: 0.000000000064
# min ems: -77.65086904254635
# min mc 39.723729611955214
# Episode 223: PDE Error: 1.553097544341; False Transient Error: 1.551554978013; Iterations: 28; CG Error: 0.000000000060
# min ems: -77.43559953485746
# min mc 39.72162084997062
# Episode 224: PDE Error: 1.551554306913; False Transient Error: 1.550011796692; Iterations: 27; CG Error: 0.000000000095
# min ems: -77.22142838719279
# min mc 39.7194518197408
# Episode 225: PDE Error: 1.550012149638; False Transient Error: 1.548470655349; Iterations: 27; CG Error: 0.000000000090
# min ems: -77.00834994822849
# min mc 39.717282609818604
# Episode 226: PDE Error: 1.548470989709; False Transient Error: 1.546930522255; Iterations: 27; CG Error: 0.000000000084
# min ems: -76.79635892087197
# min mc 39.71511324019762
# Episode 227: PDE Error: 1.546930835701; False Transient Error: 1.545391404468; Iterations: 27; CG Error: 0.000000000080
# min ems: -76.58545022250581
# min mc 39.71294373094828
# Episode 228: PDE Error: 1.545391695458; False Transient Error: 1.543853308757; Iterations: 27; CG Error: 0.000000000075
# min ems: -76.37561888717288
# min mc 39.710774102215794
# Episode 229: PDE Error: 1.543853576218; False Transient Error: 1.542316241581; Iterations: 27; CG Error: 0.000000000071
# min ems: -76.16686001721669
# min mc 39.70860437421778
# Episode 230: PDE Error: 1.542316484729; False Transient Error: 1.540780209019; Iterations: 27; CG Error: 0.000000000066
# min ems: -75.95916876355095
# min mc 39.70643456724192
# Episode 231: PDE Error: 1.540780427342; False Transient Error: 1.539245216907; Iterations: 27; CG Error: 0.000000000063
# min ems: -75.75254031907684
# min mc 39.70426470164389
# Episode 232: PDE Error: 1.539245410084; False Transient Error: 1.537710601835; Iterations: 26; CG Error: 0.000000000098
# min ems: -75.54698040107586
# min mc 39.702094798197834
# Episode 233: PDE Error: 1.537711415187; False Transient Error: 1.536177744052; Iterations: 26; CG Error: 0.000000000092
# min ems: -75.34247643156829
# min mc 39.69992487730577
# Episode 234: PDE Error: 1.536178481738; False Transient Error: 1.534645945931; Iterations: 26; CG Error: 0.000000000086
# min ems: -75.13902125830909
# min mc 39.69775495944631
# Episode 235: PDE Error: 1.534646612316; False Transient Error: 1.533115210739; Iterations: 26; CG Error: 0.000000000081
# min ems: -74.93660947284455
# min mc 39.69558506517248
# Episode 236: PDE Error: 1.533115810034; False Transient Error: 1.531585542313; Iterations: 26; CG Error: 0.000000000076
# min ems: -74.73523626916588
# min mc 39.69341521510768
# Episode 237: PDE Error: 1.531586078405; False Transient Error: 1.530056944777; Iterations: 26; CG Error: 0.000000000072
# min ems: -74.534897069138
# min mc 39.69124542994179
# Episode 238: PDE Error: 1.530057421244; False Transient Error: 1.528529422400; Iterations: 26; CG Error: 0.000000000067
# min ems: -74.33558739438737
# min mc 39.68907573042803
# Episode 239: PDE Error: 1.528529842592; False Transient Error: 1.527002979593; Iterations: 26; CG Error: 0.000000000063
# min ems: -74.13730282209126
# min mc 39.68690613738015
# Episode 240: PDE Error: 1.527003346661; False Transient Error: 1.525477620896; Iterations: 26; CG Error: 0.000000000059
# min ems: -73.94003897060124
# min mc 39.68473667166973
# Episode 241: PDE Error: 1.525477937778; False Transient Error: 1.523953350883; Iterations: 26; CG Error: 0.000000000056
# min ems: -73.74379149547387
# min mc 39.68256735422374
# Episode 242: PDE Error: 1.523953620357; False Transient Error: 1.522431203017; Iterations: 25; CG Error: 0.000000000094
# min ems: -73.54855908221171
# min mc 39.68039820575177
# Episode 243: PDE Error: 1.522430344310; False Transient Error: 1.520909020149; Iterations: 25; CG Error: 0.000000000089
# min ems: -73.35433526632258
# min mc 39.67822924734194
# Episode 244: PDE Error: 1.520908178061; False Transient Error: 1.519387950422; Iterations: 25; CG Error: 0.000000000083
# min ems: -73.1611149312792
# min mc 39.676060500125324
# Episode 245: PDE Error: 1.519387124407; False Transient Error: 1.517867997001; Iterations: 25; CG Error: 0.000000000078
# min ems: -72.96889359473555
# min mc 39.67389198527088
# Episode 246: PDE Error: 1.517867186492; False Transient Error: 1.516349163350; Iterations: 25; CG Error: 0.000000000074
# min ems: -72.77766705599313
# min mc 39.671723723985565
# Episode 247: PDE Error: 1.516348367721; False Transient Error: 1.514831453097; Iterations: 25; CG Error: 0.000000000069
# min ems: -72.58743123882613
# min mc 39.669555737513974
# Episode 248: PDE Error: 1.514830671701; False Transient Error: 1.513314870022; Iterations: 25; CG Error: 0.000000000065
# min ems: -72.39818212561437
# min mc 39.6673880471379
# Episode 249: PDE Error: 1.513314102190; False Transient Error: 1.511799418016; Iterations: 25; CG Error: 0.000000000061
# min ems: -72.20991573182933
# min mc 39.66522067417553
# Episode 250: PDE Error: 1.511798663055; False Transient Error: 1.510285101026; Iterations: 25; CG Error: 0.000000000058
# min ems: -72.02262809737331
# min mc 39.66305363998105
# Episode 251: PDE Error: 1.510284358246; False Transient Error: 1.508771923067; Iterations: 25; CG Error: 0.000000000054
# min ems: -71.83631528471952
# min mc 39.660886965943284
# Episode 252: PDE Error: 1.508771191770; False Transient Error: 1.507260803055; Iterations: 24; CG Error: 0.000000000095
# min ems: -71.6509834591596
# min mc 39.658720673018756
# Episode 253: PDE Error: 1.507259195594; False Transient Error: 1.505749879227; Iterations: 24; CG Error: 0.000000000089
# min ems: -71.46662118474023
# min mc 39.65655478276779
# Episode 254: PDE Error: 1.505748332006; False Transient Error: 1.504240099840; Iterations: 24; CG Error: 0.000000000084
# min ems: -71.28322207410484
# min mc 39.654389316766746
# Episode 255: PDE Error: 1.504238609105; False Transient Error: 1.502731471858; Iterations: 24; CG Error: 0.000000000079
# min ems: -71.10078148008431
# min mc 39.65222429660599
# Episode 256: PDE Error: 1.502730033992; False Transient Error: 1.501224001242; Iterations: 24; CG Error: 0.000000000074
# min ems: -70.91929538536951
# min mc 39.6500597438922
# Episode 257: PDE Error: 1.501222613007; False Transient Error: 1.499717693536; Iterations: 24; CG Error: 0.000000000070
# min ems: -70.73876001016323
# min mc 39.64789568024935
# Episode 258: PDE Error: 1.499716351885; False Transient Error: 1.498212553829; Iterations: 24; CG Error: 0.000000000066
# min ems: -70.55917166821499
# min mc 39.64573212731956
# Episode 259: PDE Error: 1.498211255900; False Transient Error: 1.496708586856; Iterations: 24; CG Error: 0.000000000062
# min ems: -70.38052671358018
# min mc 39.64356910676379
# Episode 260: PDE Error: 1.496707329963; False Transient Error: 1.495205797181; Iterations: 24; CG Error: 0.000000000059
# min ems: -70.20282152126
# min mc 39.64140664026205
# Episode 261: PDE Error: 1.495204578707; False Transient Error: 1.493704189204; Iterations: 24; CG Error: 0.000000000055
# min ems: -70.02605248130936
# min mc 39.639244749513125
# Episode 262: PDE Error: 1.493703006538; False Transient Error: 1.492203766776; Iterations: 24; CG Error: 0.000000000052
# min ems: -69.85021599791415
# min mc 39.63708345623431
# Episode 263: PDE Error: 1.492202617716; False Transient Error: 1.490704533871; Iterations: 24; CG Error: 0.000000000049
# min ems: -69.67530848981029
# min mc 39.634922782160984
# Episode 264: PDE Error: 1.490703416368; False Transient Error: 1.489205585284; Iterations: 23; CG Error: 0.000000000100
# min ems: -69.50132443018265
# min mc 39.632762749167405
# Episode 265: PDE Error: 1.489205439343; False Transient Error: 1.487708846732; Iterations: 23; CG Error: 0.000000000094
# min ems: -69.32826118187812
# min mc 39.63060337899213
# Episode 266: PDE Error: 1.487708655432; False Transient Error: 1.486213306189; Iterations: 23; CG Error: 0.000000000088
# min ems: -69.15611564842543
# min mc 39.628444693391856
# Episode 267: PDE Error: 1.486213068337; False Transient Error: 1.484718967506; Iterations: 23; CG Error: 0.000000000083
# min ems: -68.98488464626391
# min mc 39.626286714143355
# Episode 268: PDE Error: 1.484718681777; False Transient Error: 1.483225834302; Iterations: 23; CG Error: 0.000000000078
# min ems: -68.81456498551658
# min mc 39.6241294630413
# Episode 269: PDE Error: 1.483225499485; False Transient Error: 1.481733909595; Iterations: 23; CG Error: 0.000000000072
# min ems: -68.64515348810218
# min mc 39.62197296189725
# Episode 270: PDE Error: 1.481733525201; False Transient Error: 1.480243195471; Iterations: 23; CG Error: 0.000000000066
# min ems: -68.47664699156492
# min mc 39.61981723253807
# Episode 271: PDE Error: 1.480242762685; False Transient Error: 1.478753692692; Iterations: 23; CG Error: 0.000000000061
# min ems: -68.30904234063532
# min mc 39.617662296805335
# Episode 272: PDE Error: 1.478753215726; False Transient Error: 1.477265400755; Iterations: 23; CG Error: 0.000000000056
# min ems: -68.14233635953404
# min mc 39.615508176554556
# Episode 273: PDE Error: 1.477264888156; False Transient Error: 1.475776933281; Iterations: 22; CG Error: 0.000000000099
# min ems: -67.97652791871064
# min mc 39.61335489414041
# Episode 274: PDE Error: 1.475777777106; False Transient Error: 1.474291134462; Iterations: 22; CG Error: 0.000000000095
# min ems: -67.8116099466298
# min mc 39.61120247133923
# Episode 275: PDE Error: 1.474291904657; False Transient Error: 1.472806567083; Iterations: 22; CG Error: 0.000000000091
# min ems: -67.64757803164078
# min mc 39.609050929951074
# Episode 276: PDE Error: 1.472807270606; False Transient Error: 1.471323232712; Iterations: 22; CG Error: 0.000000000089
# min ems: -67.48442874842627
# min mc 39.6069002917998
# ...
# min mc 39.58758880122291
# Episode 286: PDE Error: 1.458029480698; False Transient Error: 1.456558424252; Iterations: 22; CG Error: 0.000000000061
# min ems: -65.90081987607468
# min mc 39.58544839805983
# Episode 287: PDE Error: 1.456558620773; False Transient Error: 1.455088872760; Iterations: 22; CG Error: 0.000000000058
# min ems: -65.74717984355598
# min mc 39.58330913869515
# Episode 288: PDE Error: 1.455089031337; False Transient Error: 1.453620593753; Iterations: 22; CG Error: 0.000000000054
# min ems: -65.59438554007723
# min mc 39.58117104498516
# Episode 289: PDE Error: 1.453620715405; False Transient Error: 1.452153590154; Iterations: 22; CG Error: 0.000000000051
# min ems: -65.44243379401905
# min mc 39.5790341387775
# Episode 290: PDE Error: 1.452153675927; False Transient Error: 1.450687864743; Iterations: 22; CG Error: 0.000000000049
# min ems: -65.29132144154191
# min mc 39.5768984419098
# Episode 291: PDE Error: 1.450687915791; False Transient Error: 1.449223420301; Iterations: 22; CG Error: 0.000000000046
# min ems: -65.14104532851695
# min mc 39.574763976208494
# Episode 292: PDE Error: 1.449223437813; False Transient Error: 1.447760864853; Iterations: 21; CG Error: 0.000000000098
# min ems: -64.99161332830063
# min mc 39.57263076355667
# Episode 293: PDE Error: 1.447760228500; False Transient Error: 1.446298963830; Iterations: 21; CG Error: 0.000000000093
# min ems: -64.84301417506452
# min mc 39.57049882573347
# Episode 294: PDE Error: 1.446298305556; False Transient Error: 1.444838349579; Iterations: 21; CG Error: 0.000000000089
# min ems: -64.69524186922425
# min mc 39.56836818450862
# Episode 295: PDE Error: 1.444837672054; False Transient Error: 1.443379025303; Iterations: 21; CG Error: 0.000000000084
# min ems: -64.54829230761075
# min mc 39.56623886163907
# Episode 296: PDE Error: 1.443378330927; False Transient Error: 1.441920994058; Iterations: 21; CG Error: 0.000000000080
# min ems: -64.40216210124252
# min mc 39.5641108788674
# Episode 297: PDE Error: 1.441920284964; False Transient Error: 1.440464258665; Iterations: 21; CG Error: 0.000000000076
# min ems: -64.25684813974966
# min mc 39.56198425791949
# Episode 298: PDE Error: 1.440463536819; False Transient Error: 1.439008821843; Iterations: 21; CG Error: 0.000000000073
# min ems: -64.11234742326772
# min mc 39.55985902050349
# Episode 299: PDE Error: 1.439008089012; False Transient Error: 1.437554686186; Iterations: 21; CG Error: 0.000000000069
# min ems: -63.96865699524985
# min mc 39.557735188307916
# Episode 300: PDE Error: 1.437553943928; False Transient Error: 1.436101854107; Iterations: 21; CG Error: 0.000000000066
# min ems: -63.82577391520691
# min mc 39.555612783000285
# Episode 301: PDE Error: 1.436101103829; False Transient Error: 1.434650327910; Iterations: 21; CG Error: 0.000000000062
# min ems: -63.68369524799532
# min mc 39.553491826225866
# Episode 302: PDE Error: 1.434649570855; False Transient Error: 1.433200109766; Iterations: 21; CG Error: 0.000000000059
# min ems: -63.54241805986655
# min mc 39.551372339606104
# Episode 303: PDE Error: 1.433199347031; False Transient Error: 1.431751201710; Iterations: 21; CG Error: 0.000000000056
# min ems: -63.40193941755123
# min mc 39.549254344737626
# Episode 304: PDE Error: 1.431750434268; False Transient Error: 1.430303605673; Iterations: 21; CG Error: 0.000000000053
# min ems: -63.26225638841107
# min mc 39.54713786319073
# Episode 305: PDE Error: 1.430302834370; False Transient Error: 1.428857323446; Iterations: 21; CG Error: 0.000000000051
# min ems: -63.1233660411935
# min mc 39.54502291650855
# Episode 306: PDE Error: 1.428856549039; False Transient Error: 1.427412356722; Iterations: 21; CG Error: 0.000000000048
# min ems: -62.98526544649977
# min mc 39.542909526205314
# Episode 307: PDE Error: 1.427411579873; False Transient Error: 1.425969895695; Iterations: 20; CG Error: 0.000000000099
# min ems: -62.84794703508966
# min mc 39.540797713368605
# Episode 308: PDE Error: 1.425967940253; False Transient Error: 1.424527519300; Iterations: 20; CG Error: 0.000000000095
# min ems: -62.71141072122535
# min mc 39.538687499531264
# Episode 309: PDE Error: 1.424525609277; False Transient Error: 1.423086457953; Iterations: 20; CG Error: 0.000000000090
# min ems: -62.5756545639839
# min mc 39.5365789061847
# Episode 310: PDE Error: 1.423084591774; False Transient Error: 1.421646715340; Iterations: 20; CG Error: 0.000000000087
# min ems: -62.4406760709998
# min mc 39.53447195477484
# Episode 311: PDE Error: 1.421644891499; False Transient Error: 1.420208294304; Iterations: 20; CG Error: 0.000000000083
# min ems: -62.30647257469859
# min mc 39.53236666670346
# Episode 312: PDE Error: 1.420206511378; False Transient Error: 1.418771197401; Iterations: 20; CG Error: 0.000000000079
# min ems: -62.17304134095696
# min mc 39.53026306332897
# Episode 313: PDE Error: 1.418769453674; False Transient Error: 1.417335426053; Iterations: 20; CG Error: 0.000000000076
# min ems: -62.04037960094803
# min mc 39.52816116596653
# Episode 314: PDE Error: 1.417333720178; False Transient Error: 1.415900981569; Iterations: 20; CG Error: 0.000000000072
# min ems: -61.9084845621891
# min mc 39.52606099588846
# Episode 315: PDE Error: 1.415899312303; False Transient Error: 1.414467864996; Iterations: 20; CG Error: 0.000000000069
# min ems: -61.77735341355142
# min mc 39.52396257432395
# Episode 316: PDE Error: 1.414466231158; False Transient Error: 1.413036077208; Iterations: 20; CG Error: 0.000000000066
# min ems: -61.64698332884026
# min mc 39.521865922459035
# Episode 317: PDE Error: 1.413034477608; False Transient Error: 1.411605618821; Iterations: 20; CG Error: 0.000000000063
# min ems: -61.51737146970492
# min mc 39.519771061436344
# Episode 318: PDE Error: 1.411604052321; False Transient Error: 1.410176490310; Iterations: 20; CG Error: 0.000000000060
# min ems: -61.38851498833145
# min mc 39.517678012354644
# Episode 319: PDE Error: 1.410174955802; False Transient Error: 1.408748692032; Iterations: 20; CG Error: 0.000000000058
# min ems: -61.26041102979394
# min mc 39.51558679626834
# Episode 320: PDE Error: 1.408747188418; False Transient Error: 1.407322224189; Iterations: 20; CG Error: 0.000000000055
# min ems: -61.1330567340665
# min mc 39.513497434186924
# Episode 321: PDE Error: 1.407320750413; False Transient Error: 1.405897086875; Iterations: 20; CG Error: 0.000000000053
# min ems: -61.006449237825855
# min mc 39.51140994707423
# Episode 322: PDE Error: 1.405895641926; False Transient Error: 1.404473280095; Iterations: 20; CG Error: 0.000000000050
# min ems: -60.88058567583555
# min mc 39.50932435584752
# Episode 323: PDE Error: 1.404471862992; False Transient Error: 1.403050803867; Iterations: 20; CG Error: 0.000000000048
# min ems: -60.75546318239314
# min mc 39.50724068137729
# Episode 324: PDE Error: 1.403049413547; False Transient Error: 1.401629657900; Iterations: 20; CG Error: 0.000000000046
# min ems: -60.63107889227159
# min mc 39.50515894448617
# Episode 325: PDE Error: 1.401628293438; False Transient Error: 1.400209841922; Iterations: 20; CG Error: 0.000000000044
# min ems: -60.50742994154987
# min mc 39.503079165948186
# Episode 326: PDE Error: 1.400208502429; False Transient Error: 1.398790992962; Iterations: 19; CG Error: 0.000000000098
# min ems: -60.384522023969694
# min mc 39.50100136624296
# Episode 327: PDE Error: 1.398790047964; False Transient Error: 1.397373855322; Iterations: 19; CG Error: 0.000000000094
# min ems: -60.26234586438885
# min mc 39.498925566098016
# Episode 328: PDE Error: 1.397372925490; False Transient Error: 1.395958048779; Iterations: 19; CG Error: 0.000000000091
# min ems: -60.14089633690058
# min mc 39.49685178618054
# Episode 329: PDE Error: 1.395957133403; False Transient Error: 1.394543571816; Iterations: 19; CG Error: 0.000000000087
# min ems: -60.020169823036085
# min mc 39.494780047098
# Episode 330: PDE Error: 1.394542670206; False Transient Error: 1.393130422975; Iterations: 19; CG Error: 0.000000000084
# min ems: -59.90016327084524
# min mc 39.49271036939817
# Episode 331: PDE Error: 1.393129534483; False Transient Error: 1.391718600895; Iterations: 19; CG Error: 0.000000000080
# min ems: -59.78087384518434
# min mc 39.49064277356975
# Episode 332: PDE Error: 1.391717724873; False Transient Error: 1.390308104218; Iterations: 19; CG Error: 0.000000000077
# min ems: -59.66229879208759
# min mc 39.48857728004245
# Episode 333: PDE Error: 1.390307240045; False Transient Error: 1.388898931613; Iterations: 19; CG Error: 0.000000000074
# min ems: -59.544435384398454
# min mc 39.486513909186954
# Episode 334: PDE Error: 1.388898078683; False Transient Error: 1.387491081739; Iterations: 19; CG Error: 0.000000000071
# min ems: -59.42728089984346
# min mc 39.48445268131445
# Episode 335: PDE Error: 1.387490239463; False Transient Error: 1.386084553227; Iterations: 19; CG Error: 0.000000000068
# min ems: -59.31083261237713
# min mc 39.48239361667674
# Episode 336: PDE Error: 1.386083721041; False Transient Error: 1.384679344676; Iterations: 19; CG Error: 0.000000000065
# min ems: -59.19508778958162
# min mc 39.480336735465535
# Episode 337: PDE Error: 1.384678522035; False Transient Error: 1.383275454640; Iterations: 19; CG Error: 0.000000000063
# min ems: -59.08004369233989
# min mc 39.478282057812095
# Episode 338: PDE Error: 1.383274641022; False Transient Error: 1.381872881618; Iterations: 19; CG Error: 0.000000000060
# min ems: -58.96569757550359
# min mc 39.47622960378674
# Episode 339: PDE Error: 1.381872076516; False Transient Error: 1.380471624045; Iterations: 19; CG Error: 0.000000000058
# min ems: -58.852046689038396
# min mc 39.47417939339814
# Episode 340: PDE Error: 1.380470826970; False Transient Error: 1.379071680281; Iterations: 19; CG Error: 0.000000000056
# min ems: -58.73908827914882
# min mc 39.47213144659269
# Episode 341: PDE Error: 1.379070890765; False Transient Error: 1.377673048604; Iterations: 19; CG Error: 0.000000000053
# min ems: -58.62681958933615
# min mc 39.470085783254
# Episode 342: PDE Error: 1.377672266207; False Transient Error: 1.376275727238; Iterations: 19; CG Error: 0.000000000051
# min ems: -58.51523786129091
# min mc 39.46804242320222
# Episode 343: PDE Error: 1.376274951520; False Transient Error: 1.374879714289; Iterations: 19; CG Error: 0.000000000049
# min ems: -58.404340335797656
# min mc 39.46600138619304
# Episode 344: PDE Error: 1.374878944845; False Transient Error: 1.373483566362; Iterations: 18; CG Error: 0.000000000100
# min ems: -58.29412014191331
# min mc 39.46396269221584
# Episode 345: PDE Error: 1.373484230065; False Transient Error: 1.372090210426; Iterations: 18; CG Error: 0.000000000096
# min ems: -58.18457689857009
# min mc 39.46192636083942
# Episode 346: PDE Error: 1.372090832601; False Transient Error: 1.370698163728; Iterations: 18; CG Error: 0.000000000093
# min ems: -58.075708615570925
# min mc 39.45989241157165
# Episode 347: PDE Error: 1.370698745682; False Transient Error: 1.369307420841; Iterations: 18; CG Error: 0.000000000090
# min ems: -57.96751285291701
# min mc 39.45786086386229
# Episode 348: PDE Error: 1.369307963797; False Transient Error: 1.367917977212; Iterations: 18; CG Error: 0.000000000086
# min ems: -57.859987051313816
# min mc 39.455831737100546
# Episode 349: PDE Error: 1.367918482344; False Transient Error: 1.366529828952; Iterations: 18; CG Error: 0.000000000083
# min ems: -57.75312861793989
# min mc 39.45380505061341
# Episode 350: PDE Error: 1.366530297357; False Transient Error: 1.365142972585; Iterations: 18; CG Error: 0.000000000080
# min ems: -57.64693494448584
# min mc 39.45178082366329
# Episode 351: PDE Error: 1.365143405310; False Transient Error: 1.363757404905; Iterations: 18; CG Error: 0.000000000078
# min ems: -57.54140340906083
# min mc 39.4497590754469
# Episode 352: PDE Error: 1.363757802963; False Transient Error: 1.362373122822; Iterations: 18; CG Error: 0.000000000075
# min ems: -57.43653137566184
# min mc 39.447739825093535
# Episode 353: PDE Error: 1.362373487268; False Transient Error: 1.360990123453; Iterations: 18; CG Error: 0.000000000072
# min ems: -57.33231619418967
# min mc 39.44572309166362
# Episode 354: PDE Error: 1.360990455266; False Transient Error: 1.359608403967; Iterations: 18; CG Error: 0.000000000070
# min ems: -57.2287552014345
# min mc 39.44370889414771
# Episode 355: PDE Error: 1.359608704035; False Transient Error: 1.358227961477; Iterations: 18; CG Error: 0.000000000067
# min ems: -57.125845722311816
# min mc 39.441697251465364
# Episode 356: PDE Error: 1.358228230653; False Transient Error: 1.356848793017; Iterations: 18; CG Error: 0.000000000065
# min ems: -57.023585071553356
# min mc 39.43968818246376
# Episode 357: PDE Error: 1.356849032168; False Transient Error: 1.355470895439; Iterations: 18; CG Error: 0.000000000063
# min ems: -56.92197055518438
# min mc 39.43768170591694
# Episode 358: PDE Error: 1.355471105595; False Transient Error: 1.354094265960; Iterations: 18; CG Error: 0.000000000060
# min ems: -56.82099947226009
# min mc 39.435677840524924
# Episode 359: PDE Error: 1.354094447861; False Transient Error: 1.352718901464; Iterations: 18; CG Error: 0.000000000058
# min ems: -56.720669116271665
# min mc 39.4336766049127
# Episode 360: PDE Error: 1.352719055818; False Transient Error: 1.351344798743; Iterations: 18; CG Error: 0.000000000056
# min ems: -56.62097677645816
# min mc 39.43167801762928
# Episode 361: PDE Error: 1.351344926245; False Transient Error: 1.349971954502; Iterations: 18; CG Error: 0.000000000054
# min ems: -56.5219197388944
# min mc 39.42968209714725
# Episode 362: PDE Error: 1.349972055841; False Transient Error: 1.348600365397; Iterations: 18; CG Error: 0.000000000052
# min ems: -56.42349528754549
# min mc 39.427688861861455
# Episode 363: PDE Error: 1.348600441224; False Transient Error: 1.347230027995; Iterations: 18; CG Error: 0.000000000051
# min ems: -56.325700705183266
# min mc 39.4256983300886
# Episode 364: PDE Error: 1.347230078934; False Transient Error: 1.345860938774; Iterations: 18; CG Error: 0.000000000049
# min ems: -56.22853327417514
# min mc 39.42371052006657
# Episode 365: PDE Error: 1.345860965432; False Transient Error: 1.344493094150; Iterations: 18; CG Error: 0.000000000047
# min ems: -56.13199027717642
# min mc 39.421725449953186
# Episode 366: PDE Error: 1.344493097104; False Transient Error: 1.343126490368; Iterations: 18; CG Error: 0.000000000046
# min ems: -56.03606899764907
# min mc 39.41974313782594
# Episode 367: PDE Error: 1.343126470270; False Transient Error: 1.341761123779; Iterations: 18; CG Error: 0.000000000044
# min ems: -55.940766720451876
# min mc 39.417763601681216
# Episode 368: PDE Error: 1.341761081174; False Transient Error: 1.340396990587; Iterations: 18; CG Error: 0.000000000043
# min ems: -55.8460807322989
# min mc 39.415786859433844
# Episode 369: PDE Error: 1.340396925989; False Transient Error: 1.339034086924; Iterations: 18; CG Error: 0.000000000041
# min ems: -55.75200832219414
# min mc 39.41381292891588
# Episode 370: PDE Error: 1.339034000825; False Transient Error: 1.337672423923; Iterations: 17; CG Error: 0.000000000099
# min ems: -55.65855413372863
# min mc 39.41184182830448
# Episode 371: PDE Error: 1.337672293575; False Transient Error: 1.336311959815; Iterations: 17; CG Error: 0.000000000096
# min ems: -55.56570977574147
# min mc 39.40987357517917
# Episode 372: PDE Error: 1.336311806036; False Transient Error: 1.334952711318; Iterations: 17; CG Error: 0.000000000093
# min ems: -55.47347045834381
# min mc 39.40790818704789
# Episode 373: PDE Error: 1.334952534578; False Transient Error: 1.333594674782; Iterations: 17; CG Error: 0.000000000090
# min ems: -55.38183278346361
# min mc 39.40594568134633
# Episode 374: PDE Error: 1.333594475589; False Transient Error: 1.332237846560; Iterations: 17; CG Error: 0.000000000087
# min ems: -55.29079389700368
# min mc 39.40398607543535
# Episode 375: PDE Error: 1.332237625410; False Transient Error: 1.330882222928; Iterations: 17; CG Error: 0.000000000084
# min ems: -55.20035115610336
# min mc 39.4020293865988
# Episode 376: PDE Error: 1.330881980302; False Transient Error: 1.329527800056; Iterations: 17; CG Error: 0.000000000081
# min ems: nan
# min mc nan
# <ipython-input-235-73f0e5946306>:87: RuntimeWarning: invalid value encountered in sqrt
#   ems_new =  (-b-np.sqrt(b**2 - 4*a*c))/(2*a)
# Episode 377: PDE Error: nan; False Transient Error: nan; Iterations: 18382; CG Error: nan

# %%
plt.hist(θ_list*1000, weights=πa[:,-1,-1])
plt.hist(θ_list*1000, weights=πa_o[:, 0, 0], alpha=0.3)
# Out:
# (array([0.05555556, 0.08333333, 0.13194444, 0.13888889, 0.11805556,
#         0.20138889, 0.10416667, 0.07638889, 0.0625    , 0.02777778]),
#  array([1.0154  , 1.194787, 1.374174, 1.553561, 1.732948, 1.912335,
#         2.091722, 2.271109, 2.450496, 2.629883, 2.80927 ]),
#  <BarContainer object of 10 artists>)

# %%
loc1 = np.abs(np.exp(k_grid) - 700).argmin()
# plt.plot(y_grid, v0[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
# plt.plot(y_grid, v0[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.plot(y_grid, v0[:, -1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[-1])))
plt.legend()
plt.title(r'$\phi(log(K), y), \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('ϕ_new.png', dpi=300)
plt.show()

# %%
plt.plot(1 -  ems_new/(α*λ_bar*np.exp(k_mat)))
plt.show()

# %%
# plt.plot(y_grid, ems[:, -1])
plt.plot(y_grid, ems[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ems[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'Emission, $\gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('emission_01.png', dpi=300)
# plt.ylim(0,12)
# Out:
# Text(0.5, 0, 'y')

# %%
y_grid[-50], y_mat.shape
# Out:
# (2.04, (101, 91))

# %%
plt.plot(k_grid, ems[-1], label="y = 4")
plt.xlabel("$\log K$")
plt.legend()
plt.savefig('e_logk.png')

# %%
np.exp(7), y_grid[40]
# Out:
# (1096.6331584284585, 1.6)

# %%
plt.plot(np.exp(k_grid), ems[40], label = "y = 2")
plt.plot(np.exp(k_grid), ems[-1], label = "y = 4")
plt.legend()
plt.xlabel('K')
plt.title('Emission')
# plt.savefig('emission_k_9.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Emission')

# %%
plt.plot(k_grid, ems[40], label = "y = 2")
plt.plot(k_grid, ems[-1], label = "y = 4")
plt.legend()
plt.xlabel('$\log K$')
plt.title('Emission')
# plt.savefig('emission_k_9.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Emission')

# %%
iota = 1 - ems/np.exp(k_mat)/α/λ_bar
plt.plot(y_grid, iota[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, iota[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'ι(y), $\gamma_3 = 0$, with fixed $\bar \lambda$')
plt.xlabel('y')
# plt.savefig('iota_01.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
ra = α*ϑ_bar*iota**θ
plt.plot(y_grid, ra[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ra[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'$\frac{X}{K}, \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('XK_new.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
ra = ems/np.exp(k_mat)/α
plt.plot(y_grid, ra[:, loc1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1])))
plt.plot(y_grid, ra[:, loc1+1], label=r"K $\approx$ {:.1f}".format(np.exp(k_grid[loc1+1])))
plt.legend()
plt.title(r'$\frac{E}{\alpha K}, \gamma_3 = 0$')
plt.xlabel('y')
# plt.savefig('ratio_01.png', dpi=300)
# Out:
# Text(0.5, 0, 'y')

# %%
# simulate
def simulate_logkapital(invkap, αₖ,  σₖ, κ, k0, T=100, dt=1):
    periods = int(T/dt)
    Kt = np.zeros(periods)
    i = invkap
     # log capital
    Kt[0] = np.log(k0)
    k = np.log(k0)
    for t in range(periods-1):
        k +=   (αₖ + i - κ/2*i**2 - .5*σₖ**2)*dt
        Kt[t+1] = k
    return Kt

# %%
n_temp = 16
n_carb = 9
n_θ = len(θ_list)
θ_mat = θ_list.reshape(n_temp, n_carb)
θtemp_list = np.average(θ_mat, axis=1)
θcarb_list = np.average(θ_mat, axis=0)

# %% [markdown]
# # Simulation
#
# ??:
#
# $$
# ME_t = \vartheta_t \theta \frac{1}{\lambda_t} \left[1 -  \frac{\mathcal{E}_t}{\alpha \lambda_t K_t }\right]^{\theta - 1}
# $$

# %%
class GridInterp_2d():

    def __init__(self, grids, values, method = 'Linear'):

        # unpacking
        self.grids = grids
        (self.xs, self.ys) = grids
        self.nx = len(self.xs)
        self.ny = len(self.ys)
        
        self.values = values

        assert (self.nx, self.ny) == values.shape, "ValueError: Dimensions not match"
        self.method = method

    def get_value(self, x, y):

        if self.method == 'Linear':
            
            func = RegularGridInterpolator(self.grids, self.values)
            return func([x,y])[0]

        elif self.method == 'Spline':

            func1 = CubicSpline(self.xs, self.values)
            ySpace = func1(x)
            
            func2 = CubicSpline(self.ys, ySpace)
            return func2(y)

        else:
            raise ValueError('Method Not Supported')

# %%
plt.plot(y_grid, i)
plt.show()

# %%
Time = 90
ppy = 12
pers = ppy * Time
# pers = 100
dt = Time / pers
nDims = 3 
its = 1

gridpoints = (y_grid, k_grid)
# interpolate emission
e_func_r = GridInterp_2d(gridpoints, ems, 'Linear')
def e_func(x):
    return e_func_r.get_value(x[0], x[1]) # match order
# interpolate investment
i_func_r = GridInterp_2d(gridpoints, i, 'Linear')
def i_func(x):
    return i_func_r.get_value(x[0], x[1])

# drifts for each diffusion process
def compute_μlogk(x):
    return μk +  i_func(x)  - 0.5*κ*i_func(x)**2 - 0.5*σk**2
def compute_μy(E_x):
    return  E_x*np.mean(θ_list)
def compute_μlogd(x, E_x):
    Y_x = x[0]
    dΛ = γ1 + γ2*Y_x + γ3*(Y_x - y_bar)*(Y_x >y_bar)
    ddΛ = γ2 + γ3*(Y_x > y_bar)  
    return dΛ*compute_μy(E_x) + 0.5*ddΛ*σy**2*E_x**2

# initial points

K_0 = 80/α
Y_0 = 1.1
D_0 = np.exp(γ1*Y_0 + γ2*Y_0**2 + γ3*((Y_0 - y_bar)**2)*(Y_0 >y_bar))-1
          
# stop
hist = np.zeros([pers, nDims])
e_hist = np.zeros([pers])
i_hist = np.zeros([pers])

for tm in range(pers):
    if tm == 0:
        # initial points
        hist[0,:] = [Y_0, np.log(K_0), D_0]
        e_hist[0] = e_func(hist[0,:])
        i_hist[0] = i_func(hist[0,:])

    else:
        # other periods
        hist[tm,0] = hist[tm - 1,0] + compute_μy(e_hist[tm-1])*dt# Y
        hist[tm,1] = hist[tm - 1,1] + compute_μlogk(hist[tm-1,:])*dt# logK
        hist[tm,2] = hist[tm - 1,2] + compute_μlogd(hist[tm-1,:], e_hist[tm-1])*dt # logDt
        e_hist[tm] = e_func(hist[tm,:])
        i_hist[tm] = i_func(hist[tm,:])

e_k_ratio = e_hist/np.exp(hist[:,1])/α
Iota_t = 1 - e_hist/np.exp(hist[:,1])/(α*λ_bar)
XK_t = α*θ_bar*Iota_t**θ
MUe = θ*θ_bar/λ_bar*Iota_t**(θ-1)

simul = dict(e= e_hist, states= hist)

# %%
1/3
# Out:
# 0.3333333333333333

# %%
plt.plot(np.arange(0, Time, dt), e_hist)
plt.xlabel('Years')
# plt.savefig('Et.png')
# Out:
# Text(0.5, 0, 'Years')

# %%
plt.plot(np.arange(0, Time, dt), e_k_ratio)
plt.xlabel('Years')
plt.title(r'$\frac{E_t}{\alpha K_t}$')
# plt.savefig('ratio.png')
# Out:
# Text(0.5, 1.0, '$\\frac{E_t}{\\alpha K_t}$')

# %%
plt.plot(np.arange(0, Time, dt), Iota_t)
plt.xlabel('Years')
plt.title(r"$\iota_t$")
# plt.savefig('iota_t.png')
# Out:
# Text(0.5, 1.0, '$\\iota_t$')

# %%
hist[480],e_hist[480]
# Out:
# (array([1.77112699, 7.32389031, 0.00992543]), 10.417991891849548)

# %%
plt.plot(hist[:,0])

# %%
plt.plot(simul['states'][:, 1])

# %%
plt.plot(simul['e'])
